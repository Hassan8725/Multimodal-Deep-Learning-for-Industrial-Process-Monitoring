# %%
#---import libraries relating to data manipulation, visualization---------------------------------------------------
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option("max_colwidth", None)

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import json

#-------import libraries to evaluate the deep learning model---------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, multilabel_confusion_matrix

import warnings
warnings.filterwarnings('ignore')

#------ import Deep Learning Libraries-------#

import torch
import torch.nn as nn
import torch.optim as optim
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
import pickle

import sys
sys.path.append('../../src')  # Add the 'src' directory to the path

#### Import Data Loading and Processing Functions
from multimodal.helper_functions import  reproducible_comp, get_final_df

#### Import Model Architecture
from multimodal.model_architecture import Generic1DCNN
reproducible_comp()
# Out:
# 2023-11-07 00:40:19.456604: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-07 00:40:19.456647: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-07 00:40:19.456672: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-07 00:40:19.463464: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-07 00:40:20.224949: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
file_path = "../../data/processed_data/acc_inner.pkl"
with open(file_path, 'rb') as picklefile:
    data = pickle.load(picklefile)

features_acc_inner, category_acc_inner, category_names, df_acc_inner = get_final_df(data, is_acc_data=1, is_multilabel=1)

file_path = "../../data/processed_data/acc_outer.pkl"
with open(file_path, 'rb') as picklefile:
    data = pickle.load(picklefile)

features_acc_outer, category_acc_outer, category_names, df_acc_outer = get_final_df(data, is_acc_data=1, is_multilabel=1)

merged_features_acc = np.concatenate((features_acc_inner,features_acc_outer), axis=0)
merged_category_acc = np.concatenate((category_acc_inner,category_acc_outer), axis=0)

labels = merged_category_acc.copy()
features = merged_features_acc.copy()
print("Features Shape: ", features.shape)
print("Labels Shape: ", labels.shape)
# Out:
# Features Shape:  (2680, 3)
# Labels Shape:  (2680, 4)

# %%
max_length = 500

for i in range (len(features)):
    if(len(features[i][0]<max_length)):
        features[i][0]=np.pad(features[i][0], (0,max_length-len(features[i][0])), 'constant', constant_values=(0))
        
    if(len(features[i][1]<max_length)):
        features[i][1]=np.pad(features[i][1], (0,max_length-len(features[i][1])), 'constant', constant_values=(0))
    
    if(len(features[i][2]<max_length)):
        features[i][2]=np.pad(features[i][2], (0,max_length-len(features[i][2])), 'constant', constant_values=(0))

# %%
feat= np.zeros(len(features)*3*max_length).reshape(-1, 3*max_length)
for i in range(len(features)):
    feat[i]= np.concatenate((features[i][0],features[i][1], features[i][2]), axis=None)
    

print("Updated Features Shape: ", feat.shape)
# Out:
# Updated Features Shape:  (2680, 1500)

# %%
# Specify the path where you want to save the JSON file
config_file_path = "../../02_Optuna_Runs/acceleration/best_configs/acc_merged_best_configs.json"

# Load the saved configuration
with open(config_file_path, "r") as config_file:
    best_configs = json.load(config_file)

best_params = best_configs["best_params"]
print(best_params)
# Out:
# {'lr': 5.254953458372508e-05, 'dropout_prob': 0.2838690767038667, 'hidden_channels': 63, 'n_layers': 7, 'kernel_size': 9, 'stride': 1, 'padding': 3, 'pooling_type': 'avg', 'use_batch_norm': True}

# %%
X_train = feat.reshape(-1, 1, feat.shape[1])
y_train = labels.copy()

print(X_train.shape)
print(y_train.shape)
# Out:
# (2680, 1, 1500)
# (2680, 4)

# %%
# Define the start, end, and interval
start = 0.95
end = 0.04
interval = -0.01

validation_sizes = [round(start + i * interval, 2) for i in range(int((end - start) / interval) + 1)]

# %%
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import f1_score

def multi_label_accuracy(y_true, y_pred):
    # Check if each label is correctly predicted
    label_accuracies = np.mean(y_true == y_pred, axis=0)
    # Compute the overall accuracy by taking the mean of label accuracies
    accuracy = np.mean(label_accuracies)
    return accuracy

# Convert your data to PyTorch tensors
x_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)

input_channels = 1
num_classes = 4
n_layers = best_params["n_layers"]
kernel_size = best_params["kernel_size"]
stride = best_params["stride"]
padding = best_params["padding"]
hidden_channels = best_params["hidden_channels"]
dropout_prob = best_params["dropout_prob"]
pooling_type = best_params["pooling_type"]
use_batch_norm = best_params["use_batch_norm"]

# Define your loss function and optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Lists to store training and validation loss values and results for different training sizes
results = []

num_epochs = 50

for validation_size in validation_sizes:
    try:
        print(f"Training Size: {int((1-validation_size) * 100)}%")
        train_losses_iter = []  # Store training losses for this training size
        valid_losses_iter = []  # Store validation losses for this training size

        # Split the data into training and validation sets for this training size
        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            x_train, y_train, test_size=validation_size, random_state=42
        )

        train_dataset = TensorDataset(x_train_split, y_train_split)
        valid_dataset = TensorDataset(x_valid_split, y_valid_split)

        train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
        valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

        model = Generic1DCNN(input_channels, num_classes, n_layers, kernel_size, stride, padding,
                             hidden_channels, dropout_prob, pooling_type, use_batch_norm).to(device)

        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(model.parameters(), lr=best_params["lr"])

        model.train()
        for epoch in range(num_epochs):
            running_loss = 0.0
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels.float())
                loss.backward()
                optimizer.step()

                running_loss += loss.item()

            train_losses_iter.append(running_loss / len(train_loader))

            # Validation loss calculation (similar to training loop)
            model.eval()
            valid_loss = 0.0
            with torch.no_grad():
                for inputs_valid, labels_valid in valid_loader:
                    inputs_valid, labels_valid = inputs_valid.to(device), labels_valid.to(device)
                    outputs_valid = model(inputs_valid)
                    loss_valid = criterion(outputs_valid, labels_valid.float())
                    valid_loss += loss_valid.item()

            valid_losses_iter.append(valid_loss / len(valid_loader))

            if (epoch + 1) % 10 == 0:
                print(f"Training Size: {int((1-validation_size) * 100)}%, Epoch {epoch + 1}/{num_epochs}, "
                      f"Training Loss: {running_loss / len(train_loader)}, Validation Loss: {valid_loss / len(valid_loader)}")

        # Evaluation on the validation set for this training size
        model.eval()
        y_true_valid = []
        y_pred_valid = []

        with torch.no_grad():
            for inputs, labels in valid_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                labels = labels.int()
                outputs = model(inputs)
                predicted = (outputs > 0).int()
                y_true_valid.append(labels.cpu().numpy())
                y_pred_valid.append(predicted.cpu().numpy())

        # Convert lists to NumPy arrays for calculations
        y_true_valid = np.array(y_true_valid[0]).reshape(-1, 4)
        y_pred_valid = np.array(y_pred_valid[0]).reshape(-1, 4)

        accuracy = multi_label_accuracy(y_true_valid, y_pred_valid)
        f1 = f1_score(y_true_valid, y_pred_valid, average='macro')

        results.append({
            "Training Size": int((1-validation_size) * 100),
            "Multi-label Validation Accuracy": accuracy,
            "F1 Score": f1
        })
        print(f"Accuracy: {accuracy}\n F1-Score: {f1}")
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# Training Size: 5%
# Training Size: 5%, Epoch 10/50, Training Loss: 0.69461456934611, Validation Loss: 0.6934213474392891
# Training Size: 5%, Epoch 20/50, Training Loss: 0.6933969656626383, Validation Loss: 0.6915101632475853
# Training Size: 5%, Epoch 30/50, Training Loss: 0.686481773853302, Validation Loss: 0.6897747337818145
# Training Size: 5%, Epoch 40/50, Training Loss: 0.6830974817276001, Validation Loss: 0.6881831973791123
# Training Size: 5%, Epoch 50/50, Training Loss: 0.6876249114672343, Validation Loss: 0.6863901078701019
# Accuracy: 0.59375
#  F1-Score: 0.14444444444444443
# Training Size: 6%
# Training Size: 6%, Epoch 10/50, Training Loss: 0.6956506768862406, Validation Loss: 0.6952638790011406
# Training Size: 6%, Epoch 20/50, Training Loss: 0.6938385566075643, Validation Loss: 0.6939166128635407
# Training Size: 6%, Epoch 30/50, Training Loss: 0.6928558548291525, Validation Loss: 0.6927109524607659
# Training Size: 6%, Epoch 40/50, Training Loss: 0.6916135350863138, Validation Loss: 0.6915327489376069
# Training Size: 6%, Epoch 50/50, Training Loss: 0.6904652317365011, Validation Loss: 0.6903086245059967
# Accuracy: 0.578125
#  F1-Score: 0.13636363636363635
# Training Size: 6%
# Training Size: 6%, Epoch 10/50, Training Loss: 0.6968242526054382, Validation Loss: 0.6966563478494302
# Training Size: 6%, Epoch 20/50, Training Loss: 0.6946550210316976, Validation Loss: 0.6945328467931503
# Training Size: 6%, Epoch 30/50, Training Loss: 0.6924849351247152, Validation Loss: 0.6923151123218048
# Training Size: 6%, Epoch 40/50, Training Loss: 0.6897757252057394, Validation Loss: 0.689667237110627
# Training Size: 6%, Epoch 50/50, Training Loss: 0.6866296529769897, Validation Loss: 0.6864017737217438
# Accuracy: 0.578125
#  F1-Score: 0.13636363636363635
# Training Size: 7%
# Training Size: 7%, Epoch 10/50, Training Loss: 0.6979639381170273, Validation Loss: 0.6987162690896255
# Training Size: 7%, Epoch 20/50, Training Loss: 0.6968298256397247, Validation Loss: 0.6968556810648013
# Training Size: 7%, Epoch 30/50, Training Loss: 0.6939260959625244, Validation Loss: 0.6948870634421324
# Training Size: 7%, Epoch 40/50, Training Loss: 0.6917576640844345, Validation Loss: 0.6927777024415823
# Training Size: 7%, Epoch 50/50, Training Loss: 0.6892872899770737, Validation Loss: 0.6900693254593091
# Accuracy: 0.453125
#  F1-Score: 0.23636363636363636
# Training Size: 8%
# Training Size: 8%, Epoch 10/50, Training Loss: 0.6939202100038528, Validation Loss: 0.694414054736113
# Training Size: 8%, Epoch 20/50, Training Loss: 0.6917835474014282, Validation Loss: 0.6919443057133601
# Training Size: 8%, Epoch 30/50, Training Loss: 0.6896801441907883, Validation Loss: 0.6899699752147381
# Training Size: 8%, Epoch 40/50, Training Loss: 0.6875251531600952, Validation Loss: 0.6876917466139182
# Training Size: 8%, Epoch 50/50, Training Loss: 0.685078963637352, Validation Loss: 0.6849939731451181
# Accuracy: 0.578125
#  F1-Score: 0.13636363636363635
# Training Size: 9%
# Training Size: 9%, Epoch 10/50, Training Loss: 0.681485390663147, Validation Loss: 0.6808234014009175
# Training Size: 9%, Epoch 20/50, Training Loss: 0.6770535588264466, Validation Loss: 0.6766589048661684
# Training Size: 9%, Epoch 30/50, Training Loss: 0.670907723903656, Validation Loss: 0.6715521420303144
# Training Size: 9%, Epoch 40/50, Training Loss: 0.6656494855880737, Validation Loss: 0.6644617099510995
# Training Size: 9%, Epoch 50/50, Training Loss: 0.6520786046981811, Validation Loss: 0.6538114955550746
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 10%
# Training Size: 10%, Epoch 10/50, Training Loss: 0.69308842420578, Validation Loss: 0.6933253940783048
# Training Size: 10%, Epoch 20/50, Training Loss: 0.6893340110778808, Validation Loss: 0.6894551374410328
# Training Size: 10%, Epoch 30/50, Training Loss: 0.6842286467552186, Validation Loss: 0.6841735149684706
# Training Size: 10%, Epoch 40/50, Training Loss: 0.676780641078949, Validation Loss: 0.6762696426165732
# Training Size: 10%, Epoch 50/50, Training Loss: 0.6663223147392273, Validation Loss: 0.6659373060653084
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 12%
# Training Size: 12%, Epoch 10/50, Training Loss: 0.6915248731772105, Validation Loss: 0.6895158870800121
# Training Size: 12%, Epoch 20/50, Training Loss: 0.6836858789126078, Validation Loss: 0.683157928892084
# Training Size: 12%, Epoch 30/50, Training Loss: 0.6791889369487762, Validation Loss: 0.675360073914399
# Training Size: 12%, Epoch 40/50, Training Loss: 0.6726672152678171, Validation Loss: 0.6661887104446823
# Training Size: 12%, Epoch 50/50, Training Loss: 0.6565748453140259, Validation Loss: 0.6541323178523296
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 13%
# Training Size: 13%, Epoch 10/50, Training Loss: 0.6838080684343973, Validation Loss: 0.6843093971948366
# Training Size: 13%, Epoch 20/50, Training Loss: 0.6767736176649729, Validation Loss: 0.6773129057239842
# Training Size: 13%, Epoch 30/50, Training Loss: 0.6672026614348093, Validation Loss: 0.6681423847739761
# Training Size: 13%, Epoch 40/50, Training Loss: 0.6533446907997131, Validation Loss: 0.6535322392309034
# Training Size: 13%, Epoch 50/50, Training Loss: 0.6378726263840994, Validation Loss: 0.6393923356726363
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 14%
# Training Size: 14%, Epoch 10/50, Training Loss: 0.6939772963523865, Validation Loss: 0.6945202576147543
# Training Size: 14%, Epoch 20/50, Training Loss: 0.6891317864259084, Validation Loss: 0.6895872193413812
# Training Size: 14%, Epoch 30/50, Training Loss: 0.6834628780682882, Validation Loss: 0.6839928546467343
# Training Size: 14%, Epoch 40/50, Training Loss: 0.6762071549892426, Validation Loss: 0.6764338145384917
# Training Size: 14%, Epoch 50/50, Training Loss: 0.663535475730896, Validation Loss: 0.6636826025473105
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 15%
# Training Size: 15%, Epoch 10/50, Training Loss: 0.682803852217538, Validation Loss: 0.6823327640692393
# Training Size: 15%, Epoch 20/50, Training Loss: 0.6745750478335789, Validation Loss: 0.6741732276148267
# Training Size: 15%, Epoch 30/50, Training Loss: 0.6656997885022845, Validation Loss: 0.6647170037031174
# Training Size: 15%, Epoch 40/50, Training Loss: 0.6500327501978193, Validation Loss: 0.6491063468986087
# Training Size: 15%, Epoch 50/50, Training Loss: 0.6342873317854745, Validation Loss: 0.6329126805067062
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 16%
# Training Size: 16%, Epoch 10/50, Training Loss: 0.6835914424487523, Validation Loss: 0.6831705106629266
# Training Size: 16%, Epoch 20/50, Training Loss: 0.6738261750766209, Validation Loss: 0.6725146389669843
# Training Size: 16%, Epoch 30/50, Training Loss: 0.6581905228751046, Validation Loss: 0.6551944199535582
# Training Size: 16%, Epoch 40/50, Training Loss: 0.6369947024754116, Validation Loss: 0.6323283794853423
# Training Size: 16%, Epoch 50/50, Training Loss: 0.6335824983460563, Validation Loss: 0.6288208862145742
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 17%
# Training Size: 17%, Epoch 10/50, Training Loss: 0.6722215935587883, Validation Loss: 0.6708456141608102
# Training Size: 17%, Epoch 20/50, Training Loss: 0.6621057391166687, Validation Loss: 0.6594528317451477
# Training Size: 17%, Epoch 30/50, Training Loss: 0.6436931267380714, Validation Loss: 0.6436278939247131
# Training Size: 17%, Epoch 40/50, Training Loss: 0.6403539553284645, Validation Loss: 0.6314409630639213
# Training Size: 17%, Epoch 50/50, Training Loss: 0.632399320602417, Validation Loss: 0.629040401322501
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 18%
# Training Size: 18%, Epoch 10/50, Training Loss: 0.6781077906489372, Validation Loss: 0.6772954838616507
# Training Size: 18%, Epoch 20/50, Training Loss: 0.6625918745994568, Validation Loss: 0.6601855073656354
# Training Size: 18%, Epoch 30/50, Training Loss: 0.6352475732564926, Validation Loss: 0.6321328810283116
# Training Size: 18%, Epoch 40/50, Training Loss: 0.6338320448994637, Validation Loss: 0.6290367126464844
# Training Size: 18%, Epoch 50/50, Training Loss: 0.6327979639172554, Validation Loss: 0.6288281832422529
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 18%
# Training Size: 18%, Epoch 10/50, Training Loss: 0.6777230799198151, Validation Loss: 0.6752946026184979
# Training Size: 18%, Epoch 20/50, Training Loss: 0.660502627491951, Validation Loss: 0.656550654593636
# Training Size: 18%, Epoch 30/50, Training Loss: 0.6398288756608963, Validation Loss: 0.6342265378026402
# Training Size: 18%, Epoch 40/50, Training Loss: 0.6339555531740189, Validation Loss: 0.6282696881714989
# Training Size: 18%, Epoch 50/50, Training Loss: 0.6338005065917969, Validation Loss: 0.6280857920646667
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 19%
# Training Size: 19%, Epoch 10/50, Training Loss: 0.6843130323621962, Validation Loss: 0.6827433530022117
# Training Size: 19%, Epoch 20/50, Training Loss: 0.6661881340874566, Validation Loss: 0.6633598208427429
# Training Size: 19%, Epoch 30/50, Training Loss: 0.6425742639435662, Validation Loss: 0.6391477041384753
# Training Size: 19%, Epoch 40/50, Training Loss: 0.634521120124393, Validation Loss: 0.6298645612071542
# Training Size: 19%, Epoch 50/50, Training Loss: 0.6348697874281142, Validation Loss: 0.6286021874231451
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 20%
# Training Size: 20%, Epoch 10/50, Training Loss: 0.6842857996622721, Validation Loss: 0.6828098472426919
# Training Size: 20%, Epoch 20/50, Training Loss: 0.6579885019196404, Validation Loss: 0.6545786051189199
# Training Size: 20%, Epoch 30/50, Training Loss: 0.6351865596241422, Validation Loss: 0.6310851994682761
# Training Size: 20%, Epoch 40/50, Training Loss: 0.6345059076944987, Validation Loss: 0.6289406716823578
# Training Size: 20%, Epoch 50/50, Training Loss: 0.6333090530501472, Validation Loss: 0.6286175321130192
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 21%
# Training Size: 21%, Epoch 10/50, Training Loss: 0.6677153766155243, Validation Loss: 0.6640049291379524
# Training Size: 21%, Epoch 20/50, Training Loss: 0.6410024881362915, Validation Loss: 0.6352695931087841
# Training Size: 21%, Epoch 30/50, Training Loss: 0.6324404180049896, Validation Loss: 0.6276473746155248
# Training Size: 21%, Epoch 40/50, Training Loss: 0.6366226077079773, Validation Loss: 0.6275880300637448
# Training Size: 21%, Epoch 50/50, Training Loss: 0.6323611855506897, Validation Loss: 0.6272809342904524
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 23%
# Training Size: 23%, Epoch 10/50, Training Loss: 0.67313192486763, Validation Loss: 0.6710459662206245
# Training Size: 23%, Epoch 20/50, Training Loss: 0.6447270035743713, Validation Loss: 0.6413774183302214
# Training Size: 23%, Epoch 30/50, Training Loss: 0.6340363681316376, Validation Loss: 0.6282430020245638
# Training Size: 23%, Epoch 40/50, Training Loss: 0.6337009310722351, Validation Loss: 0.6275335405812119
# Training Size: 23%, Epoch 50/50, Training Loss: 0.6336144804954529, Validation Loss: 0.6272733464385524
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 24%
# Training Size: 24%, Epoch 10/50, Training Loss: 0.6720939712090925, Validation Loss: 0.6710774395614862
# Training Size: 24%, Epoch 20/50, Training Loss: 0.6395819403908469, Validation Loss: 0.6349668260663748
# Training Size: 24%, Epoch 30/50, Training Loss: 0.628317572853782, Validation Loss: 0.6271120104938745
# Training Size: 24%, Epoch 40/50, Training Loss: 0.6377639011903242, Validation Loss: 0.6267350371927023
# Training Size: 24%, Epoch 50/50, Training Loss: 0.6305248899893328, Validation Loss: 0.6270826105028391
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 25%
# Training Size: 25%, Epoch 10/50, Training Loss: 0.6597559668801047, Validation Loss: 0.6542771346867085
# Training Size: 25%, Epoch 20/50, Training Loss: 0.6328867998990145, Validation Loss: 0.6276327930390835
# Training Size: 25%, Epoch 30/50, Training Loss: 0.6337888024070046, Validation Loss: 0.6267471760511398
# Training Size: 25%, Epoch 40/50, Training Loss: 0.6313443400643088, Validation Loss: 0.6263113189488649
# Training Size: 25%, Epoch 50/50, Training Loss: 0.6297656243497675, Validation Loss: 0.6238697320222855
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 26%
# Training Size: 26%, Epoch 10/50, Training Loss: 0.6770655783739957, Validation Loss: 0.6747110332212141
# Training Size: 26%, Epoch 20/50, Training Loss: 0.6515276702967557, Validation Loss: 0.6468418836593628
# Training Size: 26%, Epoch 30/50, Training Loss: 0.6310629465363242, Validation Loss: 0.6276036308657739
# Training Size: 26%, Epoch 40/50, Training Loss: 0.6303731365637346, Validation Loss: 0.6269622329742678
# Training Size: 26%, Epoch 50/50, Training Loss: 0.6169300783764232, Validation Loss: 0.6123033377432054
# Accuracy: 0.640625
#  F1-Score: 0.0
# Training Size: 27%
# Training Size: 27%, Epoch 10/50, Training Loss: 0.6404629002014796, Validation Loss: 0.6359167310499376
# Training Size: 27%, Epoch 20/50, Training Loss: 0.628471260269483, Validation Loss: 0.6279709685233331
# Training Size: 27%, Epoch 30/50, Training Loss: 0.6239535758892695, Validation Loss: 0.6247229441519706
# Training Size: 27%, Epoch 40/50, Training Loss: 0.5441785554091135, Validation Loss: 0.5433626790200511
# Training Size: 27%, Epoch 50/50, Training Loss: 0.44841083884239197, Validation Loss: 0.470522073007399
# Accuracy: 0.75390625
#  F1-Score: 0.5893939393939394
# Training Size: 28%
# Training Size: 28%, Epoch 10/50, Training Loss: 0.6724676887194315, Validation Loss: 0.6697358681309608
# Training Size: 28%, Epoch 20/50, Training Loss: 0.6292425443728765, Validation Loss: 0.628296188769802
# Training Size: 28%, Epoch 30/50, Training Loss: 0.6275079051653544, Validation Loss: 0.6266932910488497
# Training Size: 28%, Epoch 40/50, Training Loss: 0.5857369055350622, Validation Loss: 0.5832895117421304
# Training Size: 28%, Epoch 50/50, Training Loss: 0.4551273708542188, Validation Loss: 0.4730358777507659
# Accuracy: 0.7578125
#  F1-Score: 0.5897694721750368
# Training Size: 29%
# Training Size: 29%, Epoch 10/50, Training Loss: 0.658474876330449, Validation Loss: 0.6571918308734894
# Training Size: 29%, Epoch 20/50, Training Loss: 0.6308579857532794, Validation Loss: 0.6285691340764363
# Training Size: 29%, Epoch 30/50, Training Loss: 0.6300648084053626, Validation Loss: 0.6263709008693695
# Training Size: 29%, Epoch 40/50, Training Loss: 0.5582700600990882, Validation Loss: 0.5515176792939503
# Training Size: 29%, Epoch 50/50, Training Loss: 0.4447678808982556, Validation Loss: 0.4647066920995712
# Accuracy: 0.77734375
#  F1-Score: 0.6221014964216005
# Training Size: 30%
# Training Size: 30%, Epoch 10/50, Training Loss: 0.6352106974675105, Validation Loss: 0.6317507843176524
# Training Size: 30%, Epoch 20/50, Training Loss: 0.629170087667612, Validation Loss: 0.6275906165440878
# Training Size: 30%, Epoch 30/50, Training Loss: 0.6217593963329608, Validation Loss: 0.6177075962225597
# Training Size: 30%, Epoch 40/50, Training Loss: 0.45425060162177455, Validation Loss: 0.46156724989414216
# Training Size: 30%, Epoch 50/50, Training Loss: 0.3953096385185535, Validation Loss: 0.42343869904677073
# Accuracy: 0.80859375
#  F1-Score: 0.7150398620986856
# Training Size: 31%
# Training Size: 31%, Epoch 10/50, Training Loss: 0.6554796833258408, Validation Loss: 0.6538800124464363
# Training Size: 31%, Epoch 20/50, Training Loss: 0.6276274002515353, Validation Loss: 0.6280927575867752
# Training Size: 31%, Epoch 30/50, Training Loss: 0.6117362288328317, Validation Loss: 0.6079354594493734
# Training Size: 31%, Epoch 40/50, Training Loss: 0.4526189863681793, Validation Loss: 0.46707614742476367
# Training Size: 31%, Epoch 50/50, Training Loss: 0.40713126155046314, Validation Loss: 0.43339981703922664
# Accuracy: 0.78125
#  F1-Score: 0.6878810486458734
# Training Size: 31%
# Training Size: 31%, Epoch 10/50, Training Loss: 0.6349176338740757, Validation Loss: 0.6327218475012943
# Training Size: 31%, Epoch 20/50, Training Loss: 0.6262048695768628, Validation Loss: 0.6273096635423857
# Training Size: 31%, Epoch 30/50, Training Loss: 0.5721328684261867, Validation Loss: 0.5657868981361389
# Training Size: 31%, Epoch 40/50, Training Loss: 0.4495022509779249, Validation Loss: 0.4621254236533724
# Training Size: 31%, Epoch 50/50, Training Loss: 0.39650770808969227, Validation Loss: 0.4315816266783353
# Accuracy: 0.78125
#  F1-Score: 0.6728063202521407
# Training Size: 32%
# Training Size: 32%, Epoch 10/50, Training Loss: 0.6285846063068935, Validation Loss: 0.628810884623692
# Training Size: 32%, Epoch 20/50, Training Loss: 0.616681022303445, Validation Loss: 0.6157471085416859
# Training Size: 32%, Epoch 30/50, Training Loss: 0.47099752724170685, Validation Loss: 0.4796036286600705
# Training Size: 32%, Epoch 40/50, Training Loss: 0.41991060759340015, Validation Loss: 0.4442619044205238
# Training Size: 32%, Epoch 50/50, Training Loss: 0.3883618116378784, Validation Loss: 0.424763482192467
# Accuracy: 0.796875
#  F1-Score: 0.7005995299001802
# Training Size: 34%
# Training Size: 34%, Epoch 10/50, Training Loss: 0.6341593623161316, Validation Loss: 0.6335362515279225
# Training Size: 34%, Epoch 20/50, Training Loss: 0.6181544462839762, Validation Loss: 0.6210990228823253
# Training Size: 34%, Epoch 30/50, Training Loss: 0.4666350185871124, Validation Loss: 0.4775400938732283
# Training Size: 34%, Epoch 40/50, Training Loss: 0.4235207358996073, Validation Loss: 0.450916445681027
# Training Size: 34%, Epoch 50/50, Training Loss: 0.3886061986287435, Validation Loss: 0.4184012253369604
# Accuracy: 0.8046875
#  F1-Score: 0.7306929590017825
# Training Size: 35%
# Training Size: 35%, Epoch 10/50, Training Loss: 0.6290355563163758, Validation Loss: 0.6298345050641468
# Training Size: 35%, Epoch 20/50, Training Loss: 0.6178692579269409, Validation Loss: 0.6172357967921666
# Training Size: 35%, Epoch 30/50, Training Loss: 0.46224303245544435, Validation Loss: 0.47117632414613453
# Training Size: 35%, Epoch 40/50, Training Loss: 0.41175511678059895, Validation Loss: 0.4327927040202277
# Training Size: 35%, Epoch 50/50, Training Loss: 0.37266872326533, Validation Loss: 0.41255528586251394
# Accuracy: 0.79296875
#  F1-Score: 0.6979336349924585
# Training Size: 36%
# Training Size: 36%, Epoch 10/50, Training Loss: 0.6231843307614326, Validation Loss: 0.6255242471341733
# Training Size: 36%, Epoch 20/50, Training Loss: 0.49047037959098816, Validation Loss: 0.4927283602732199
# Training Size: 36%, Epoch 30/50, Training Loss: 0.43549042008817196, Validation Loss: 0.44756872786415947
# Training Size: 36%, Epoch 40/50, Training Loss: 0.3867765162140131, Validation Loss: 0.41893632102895667
# Training Size: 36%, Epoch 50/50, Training Loss: 0.3556417915970087, Validation Loss: 0.39338615095173873
# Accuracy: 0.796875
#  F1-Score: 0.701290564072519
# Training Size: 37%
# Training Size: 37%, Epoch 10/50, Training Loss: 0.6250418908894062, Validation Loss: 0.6287562780910068
# Training Size: 37%, Epoch 20/50, Training Loss: 0.539600059390068, Validation Loss: 0.5288882961979618
# Training Size: 37%, Epoch 30/50, Training Loss: 0.4268730264157057, Validation Loss: 0.44194327460394967
# Training Size: 37%, Epoch 40/50, Training Loss: 0.3769698701798916, Validation Loss: 0.4112208562868613
# Training Size: 37%, Epoch 50/50, Training Loss: 0.35354829765856266, Validation Loss: 0.39569213765638844
# Accuracy: 0.79296875
#  F1-Score: 0.6768096392987234
# Training Size: 38%
# Training Size: 38%, Epoch 10/50, Training Loss: 0.623843178153038, Validation Loss: 0.6234132922612704
# Training Size: 38%, Epoch 20/50, Training Loss: 0.47996557876467705, Validation Loss: 0.4840301962999197
# Training Size: 38%, Epoch 30/50, Training Loss: 0.4399198442697525, Validation Loss: 0.4550889398042972
# Training Size: 38%, Epoch 40/50, Training Loss: 0.41125093400478363, Validation Loss: 0.4330032433454807
# Training Size: 38%, Epoch 50/50, Training Loss: 0.3880125842988491, Validation Loss: 0.4146814609949405
# Accuracy: 0.7890625
#  F1-Score: 0.6869537480063795
# Training Size: 39%
# Training Size: 39%, Epoch 10/50, Training Loss: 0.5899569111711839, Validation Loss: 0.5819257933359879
# Training Size: 39%, Epoch 20/50, Training Loss: 0.4590547452954685, Validation Loss: 0.46939435371985805
# Training Size: 39%, Epoch 30/50, Training Loss: 0.42056526156032786, Validation Loss: 0.43415513863930333
# Training Size: 39%, Epoch 40/50, Training Loss: 0.38165999861324534, Validation Loss: 0.398389723438483
# Training Size: 39%, Epoch 50/50, Training Loss: 0.35032666080138264, Validation Loss: 0.3890871290977185
# Accuracy: 0.78125
#  F1-Score: 0.688469401662805
# Training Size: 40%
# Training Size: 40%, Epoch 10/50, Training Loss: 0.6256466157296124, Validation Loss: 0.6273936056173764
# Training Size: 40%, Epoch 20/50, Training Loss: 0.5021958929650924, Validation Loss: 0.49753041909291196
# Training Size: 40%, Epoch 30/50, Training Loss: 0.41694798189051013, Validation Loss: 0.43663490277070266
# Training Size: 40%, Epoch 40/50, Training Loss: 0.3740288422388189, Validation Loss: 0.41350949154450345
# Training Size: 40%, Epoch 50/50, Training Loss: 0.3474845447961022, Validation Loss: 0.39414830047350663
# Accuracy: 0.7890625
#  F1-Score: 0.6625058275058275
# Training Size: 41%
# Training Size: 41%, Epoch 10/50, Training Loss: 0.6275626983907487, Validation Loss: 0.6262948298454285
# Training Size: 41%, Epoch 20/50, Training Loss: 0.48961534599463147, Validation Loss: 0.4871021783351898
# Training Size: 41%, Epoch 30/50, Training Loss: 0.4308772683143616, Validation Loss: 0.4417275655269623
# Training Size: 41%, Epoch 40/50, Training Loss: 0.38231999841001296, Validation Loss: 0.4082076585292816
# Training Size: 41%, Epoch 50/50, Training Loss: 0.3519481321175893, Validation Loss: 0.3793986737728119
# Accuracy: 0.80078125
#  F1-Score: 0.7094816504250466
# Training Size: 42%
# Training Size: 42%, Epoch 10/50, Training Loss: 0.6227382520834605, Validation Loss: 0.6226239275932312
# Training Size: 42%, Epoch 20/50, Training Loss: 0.46249354382356006, Validation Loss: 0.46705981850624084
# Training Size: 42%, Epoch 30/50, Training Loss: 0.3982298837767707, Validation Loss: 0.41162524819374086
# Training Size: 42%, Epoch 40/50, Training Loss: 0.34741662277115715, Validation Loss: 0.38094905138015744
# Training Size: 42%, Epoch 50/50, Training Loss: 0.3274737331602309, Validation Loss: 0.3714892911911011
# Accuracy: 0.8203125
#  F1-Score: 0.7204224700354731
# Training Size: 43%
# Training Size: 43%, Epoch 10/50, Training Loss: 0.6242909332116445, Validation Loss: 0.6246281589070956
# Training Size: 43%, Epoch 20/50, Training Loss: 0.4766332507133484, Validation Loss: 0.47436042750875157
# Training Size: 43%, Epoch 30/50, Training Loss: 0.4293718487024307, Validation Loss: 0.4387924385567506
# Training Size: 43%, Epoch 40/50, Training Loss: 0.39544613162676495, Validation Loss: 0.41069486488898593
# Training Size: 43%, Epoch 50/50, Training Loss: 0.3610183712508943, Validation Loss: 0.3853928782045841
# Accuracy: 0.83203125
#  F1-Score: 0.7576134204689008
# Training Size: 43%
# Training Size: 43%, Epoch 10/50, Training Loss: 0.6233268505648563, Validation Loss: 0.6218356316288313
# Training Size: 43%, Epoch 20/50, Training Loss: 0.46156977666051763, Validation Loss: 0.468394269545873
# Training Size: 43%, Epoch 30/50, Training Loss: 0.3984357369573493, Validation Loss: 0.4139123745262623
# Training Size: 43%, Epoch 40/50, Training Loss: 0.3474901051897752, Validation Loss: 0.3896903470158577
# Training Size: 43%, Epoch 50/50, Training Loss: 0.32021035410855947, Validation Loss: 0.37869999185204506
# Accuracy: 0.8046875
#  F1-Score: 0.6897435897435897
# Training Size: 44%
# Training Size: 44%, Epoch 10/50, Training Loss: 0.6203679787485223, Validation Loss: 0.6160374457637469
# Training Size: 44%, Epoch 20/50, Training Loss: 0.458861286702909, Validation Loss: 0.45696695273121196
# Training Size: 44%, Epoch 30/50, Training Loss: 0.40158299866475555, Validation Loss: 0.41314760968089104
# Training Size: 44%, Epoch 40/50, Training Loss: 0.36030115108740957, Validation Loss: 0.3837246062854926
# Training Size: 44%, Epoch 50/50, Training Loss: 0.32869495373023183, Validation Loss: 0.3747642158220212
# Accuracy: 0.80078125
#  F1-Score: 0.7482667605618425
# Training Size: 46%
# Training Size: 46%, Epoch 10/50, Training Loss: 0.5003334745764733, Validation Loss: 0.4953023752440577
# Training Size: 46%, Epoch 20/50, Training Loss: 0.42485634982585907, Validation Loss: 0.44127520400544873
# Training Size: 46%, Epoch 30/50, Training Loss: 0.3726146772503853, Validation Loss: 0.3939418818639672
# Training Size: 46%, Epoch 40/50, Training Loss: 0.34193217754364014, Validation Loss: 0.37203849787297455
# Training Size: 46%, Epoch 50/50, Training Loss: 0.3131982654333115, Validation Loss: 0.3571050218913866
# Accuracy: 0.828125
#  F1-Score: 0.7574801587301587
# Training Size: 47%
# Training Size: 47%, Epoch 10/50, Training Loss: 0.5810325652360916, Validation Loss: 0.5664418676625127
# Training Size: 47%, Epoch 20/50, Training Loss: 0.4357432633638382, Validation Loss: 0.4381791055202484
# Training Size: 47%, Epoch 30/50, Training Loss: 0.3710433766245842, Validation Loss: 0.38869258761405945
# Training Size: 47%, Epoch 40/50, Training Loss: 0.3295760631561279, Validation Loss: 0.3554650674695554
# Training Size: 47%, Epoch 50/50, Training Loss: 0.300080519169569, Validation Loss: 0.34097286410953687
# Accuracy: 0.84375
#  F1-Score: 0.7795003607503608
# Training Size: 48%
# Training Size: 48%, Epoch 10/50, Training Loss: 0.5481528015363784, Validation Loss: 0.5273832814259962
# Training Size: 48%, Epoch 20/50, Training Loss: 0.4423613136722928, Validation Loss: 0.44944928044622595
# Training Size: 48%, Epoch 30/50, Training Loss: 0.3930065149352664, Validation Loss: 0.40421622585166583
# Training Size: 48%, Epoch 40/50, Training Loss: 0.3490054068111238, Validation Loss: 0.3654157736084678
# Training Size: 48%, Epoch 50/50, Training Loss: 0.31711843325978234, Validation Loss: 0.3581362637606534
# Accuracy: 0.8203125
#  F1-Score: 0.7457514652229289
# Training Size: 49%
# Training Size: 49%, Epoch 10/50, Training Loss: 0.5304753326234364, Validation Loss: 0.5107146203517914
# Training Size: 49%, Epoch 20/50, Training Loss: 0.443390653246925, Validation Loss: 0.4506764506751841
# Training Size: 49%, Epoch 30/50, Training Loss: 0.390709529320399, Validation Loss: 0.41100478036837146
# Training Size: 49%, Epoch 40/50, Training Loss: 0.34568787756420316, Validation Loss: 0.37437918104908685
# Training Size: 49%, Epoch 50/50, Training Loss: 0.31677043437957764, Validation Loss: 0.35638189857656305
# Accuracy: 0.8359375
#  F1-Score: 0.7879948914431674
# Training Size: 50%
# Training Size: 50%, Epoch 10/50, Training Loss: 0.5201792390573592, Validation Loss: 0.5078235339550745
# Training Size: 50%, Epoch 20/50, Training Loss: 0.4197930750392732, Validation Loss: 0.43704712248983835
# Training Size: 50%, Epoch 30/50, Training Loss: 0.3423702319463094, Validation Loss: 0.37053671904972624
# Training Size: 50%, Epoch 40/50, Training Loss: 0.30575932775224957, Validation Loss: 0.34605286660648527
# Training Size: 50%, Epoch 50/50, Training Loss: 0.28713794762179967, Validation Loss: 0.3705825238000779
# Accuracy: 0.79296875
#  F1-Score: 0.7428271318938711
# Training Size: 51%
# Training Size: 51%, Epoch 10/50, Training Loss: 0.5075409385291013, Validation Loss: 0.4995785185268947
# Training Size: 51%, Epoch 20/50, Training Loss: 0.41948367113416846, Validation Loss: 0.4285989659173148
# Training Size: 51%, Epoch 30/50, Training Loss: 0.3452124013142152, Validation Loss: 0.4027522930077144
# Training Size: 51%, Epoch 40/50, Training Loss: 0.31539475240490655, Validation Loss: 0.359588371855872
# Training Size: 51%, Epoch 50/50, Training Loss: 0.2863470207561146, Validation Loss: 0.3424454047566369
# Accuracy: 0.828125
#  F1-Score: 0.7674287612981818
# Training Size: 52%
# Training Size: 52%, Epoch 10/50, Training Loss: 0.4816776486960324, Validation Loss: 0.4771278202533722
# Training Size: 52%, Epoch 20/50, Training Loss: 0.3879632760177959, Validation Loss: 0.41641939537865774
# Training Size: 52%, Epoch 30/50, Training Loss: 0.3510637188499624, Validation Loss: 0.39131406659171697
# Training Size: 52%, Epoch 40/50, Training Loss: 0.315219138156284, Validation Loss: 0.3643692291918255
# Training Size: 52%, Epoch 50/50, Training Loss: 0.2858851917765357, Validation Loss: 0.34388750081970576
# Accuracy: 0.83203125
#  F1-Score: 0.7549816521590715
# Training Size: 53%
# Training Size: 53%, Epoch 10/50, Training Loss: 0.48072081545124884, Validation Loss: 0.47325228452682494
# Training Size: 53%, Epoch 20/50, Training Loss: 0.41148311418035755, Validation Loss: 0.42405874729156495
# Training Size: 53%, Epoch 30/50, Training Loss: 0.36265312070431915, Validation Loss: 0.37405741065740583
# Training Size: 53%, Epoch 40/50, Training Loss: 0.3223255639490874, Validation Loss: 0.35042729526758193
# Training Size: 53%, Epoch 50/50, Training Loss: 0.2990309414656266, Validation Loss: 0.3403733804821968
# Accuracy: 0.8359375
#  F1-Score: 0.7511820330969268
# Training Size: 54%
# Training Size: 54%, Epoch 10/50, Training Loss: 0.48661128075226495, Validation Loss: 0.4836826786398888
# Training Size: 54%, Epoch 20/50, Training Loss: 0.405075817004494, Validation Loss: 0.41242477744817735
# Training Size: 54%, Epoch 30/50, Training Loss: 0.3448298534621363, Validation Loss: 0.3732546970248222
# Training Size: 54%, Epoch 40/50, Training Loss: 0.31183302726434625, Validation Loss: 0.3548328325152397
# Training Size: 54%, Epoch 50/50, Training Loss: 0.2908034071974132, Validation Loss: 0.3597728744149208
# Accuracy: 0.828125
#  F1-Score: 0.7676080023917484
# Training Size: 55%
# Training Size: 55%, Epoch 10/50, Training Loss: 0.4859040267765522, Validation Loss: 0.4816204497688695
# Training Size: 55%, Epoch 20/50, Training Loss: 0.4085179530084133, Validation Loss: 0.427663969366174
# Training Size: 55%, Epoch 30/50, Training Loss: 0.3564338448146979, Validation Loss: 0.3831526417481272
# Training Size: 55%, Epoch 40/50, Training Loss: 0.31847765607138473, Validation Loss: 0.37612091083275645
# Training Size: 55%, Epoch 50/50, Training Loss: 0.29478517919778824, Validation Loss: 0.33347371848005997
# Accuracy: 0.83984375
#  F1-Score: 0.7889487009493062
# Training Size: 56%
# Training Size: 56%, Epoch 10/50, Training Loss: 0.44970638180772465, Validation Loss: 0.454479561040276
# Training Size: 56%, Epoch 20/50, Training Loss: 0.3689751277367274, Validation Loss: 0.3751924383012872
# Training Size: 56%, Epoch 30/50, Training Loss: 0.316256166746219, Validation Loss: 0.35140377283096313
# Training Size: 56%, Epoch 40/50, Training Loss: 0.2815695181488991, Validation Loss: 0.3387695848941803
# Training Size: 56%, Epoch 50/50, Training Loss: 0.2527467403560877, Validation Loss: 0.32160630900608866
# Accuracy: 0.8203125
#  F1-Score: 0.7681119667439008
# Training Size: 57%
# Training Size: 57%, Epoch 10/50, Training Loss: 0.4700521305203438, Validation Loss: 0.4695762113520974
# Training Size: 57%, Epoch 20/50, Training Loss: 0.3958229720592499, Validation Loss: 0.3969958510838057
# Training Size: 57%, Epoch 30/50, Training Loss: 0.33636025463541347, Validation Loss: 0.3595329013309981
# Training Size: 57%, Epoch 40/50, Training Loss: 0.30619187156359357, Validation Loss: 0.33792195469141006
# Training Size: 57%, Epoch 50/50, Training Loss: 0.2826876013229291, Validation Loss: 0.3262963443994522
# Accuracy: 0.83203125
#  F1-Score: 0.7513807882644045
# Training Size: 58%
# Training Size: 58%, Epoch 10/50, Training Loss: 0.46020864844322207, Validation Loss: 0.45533410211404163
# Training Size: 58%, Epoch 20/50, Training Loss: 0.36519575595855713, Validation Loss: 0.38467612531450057
# Training Size: 58%, Epoch 30/50, Training Loss: 0.3046663743257523, Validation Loss: 0.36395247280597687
# Training Size: 58%, Epoch 40/50, Training Loss: 0.2871130985021591, Validation Loss: 0.3336154686080085
# Training Size: 58%, Epoch 50/50, Training Loss: 0.2627644956111908, Validation Loss: 0.32856428457631004
# Accuracy: 0.84765625
#  F1-Score: 0.7888064971751413
# Training Size: 59%
# Training Size: 59%, Epoch 10/50, Training Loss: 0.4658031642436981, Validation Loss: 0.48016539050473106
# Training Size: 59%, Epoch 20/50, Training Loss: 0.3640862452983856, Validation Loss: 0.3931727094782723
# Training Size: 59%, Epoch 30/50, Training Loss: 0.3275142979621887, Validation Loss: 0.38648269408278996
# Training Size: 59%, Epoch 40/50, Training Loss: 0.2965917956829071, Validation Loss: 0.3587533086538315
# Training Size: 59%, Epoch 50/50, Training Loss: 0.28658694326877593, Validation Loss: 0.3440394252538681
# Accuracy: 0.8359375
#  F1-Score: 0.7720959595959597
# Training Size: 60%
# Training Size: 60%, Epoch 10/50, Training Loss: 0.4600913318303915, Validation Loss: 0.4598720792461844
# Training Size: 60%, Epoch 20/50, Training Loss: 0.36875731555315167, Validation Loss: 0.39680788972798514
# Training Size: 60%, Epoch 30/50, Training Loss: 0.3238499244818321, Validation Loss: 0.36577030841042013
# Training Size: 60%, Epoch 40/50, Training Loss: 0.2904931473044249, Validation Loss: 0.3425157473367803
# Training Size: 60%, Epoch 50/50, Training Loss: 0.27240281724012816, Validation Loss: 0.34784245140412273
# Accuracy: 0.81640625
#  F1-Score: 0.7684812402224355
# Training Size: 61%
# Training Size: 61%, Epoch 10/50, Training Loss: 0.44342648639128757, Validation Loss: 0.4394390144768883
# Training Size: 61%, Epoch 20/50, Training Loss: 0.3413637956747642, Validation Loss: 0.37551014388308807
# Training Size: 61%, Epoch 30/50, Training Loss: 0.28558143170980305, Validation Loss: 0.339252044172848
# Training Size: 61%, Epoch 40/50, Training Loss: 0.2615863147836465, Validation Loss: 0.33132216684958515
# Training Size: 61%, Epoch 50/50, Training Loss: 0.24463952160798585, Validation Loss: 0.3268516826279023
# Accuracy: 0.875
#  F1-Score: 0.8441152494078861
# Training Size: 62%
# Training Size: 62%, Epoch 10/50, Training Loss: 0.4516727523161815, Validation Loss: 0.4556737635284662
# Training Size: 62%, Epoch 20/50, Training Loss: 0.34647536048522365, Validation Loss: 0.3659966439008713
# Training Size: 62%, Epoch 30/50, Training Loss: 0.2956867768214299, Validation Loss: 0.346283046528697
# Training Size: 62%, Epoch 40/50, Training Loss: 0.2763230021183307, Validation Loss: 0.3325207456946373
# Training Size: 62%, Epoch 50/50, Training Loss: 0.24912675068928644, Validation Loss: 0.3273787396028638
# Accuracy: 0.83984375
#  F1-Score: 0.7596974764073882
# Training Size: 63%
# Training Size: 63%, Epoch 10/50, Training Loss: 0.43784676105887804, Validation Loss: 0.43389013782143593
# Training Size: 63%, Epoch 20/50, Training Loss: 0.33799198600980973, Validation Loss: 0.3482452165335417
# Training Size: 63%, Epoch 30/50, Training Loss: 0.2953166652608801, Validation Loss: 0.327905910089612
# Training Size: 63%, Epoch 40/50, Training Loss: 0.2718111221437101, Validation Loss: 0.32097107358276844
# Training Size: 63%, Epoch 50/50, Training Loss: 0.25006946535022173, Validation Loss: 0.3040894167497754
# Accuracy: 0.87109375
#  F1-Score: 0.8298039084906289
# Training Size: 64%
# Training Size: 64%, Epoch 10/50, Training Loss: 0.45682326842237403, Validation Loss: 0.4625280387699604
# Training Size: 64%, Epoch 20/50, Training Loss: 0.3477155433760749, Validation Loss: 0.375197509303689
# Training Size: 64%, Epoch 30/50, Training Loss: 0.30224309972038976, Validation Loss: 0.3546973764896393
# Training Size: 64%, Epoch 40/50, Training Loss: 0.2786428536529894, Validation Loss: 0.34322679229080677
# Training Size: 64%, Epoch 50/50, Training Loss: 0.2533559594993238, Validation Loss: 0.3309322474524379
# Accuracy: 0.83984375
#  F1-Score: 0.7875287500314495
# Training Size: 65%
# Training Size: 65%, Epoch 10/50, Training Loss: 0.4456210508942604, Validation Loss: 0.44110491474469504
# Training Size: 65%, Epoch 20/50, Training Loss: 0.3478637507983616, Validation Loss: 0.3813481529553731
# Training Size: 65%, Epoch 30/50, Training Loss: 0.300895096468074, Validation Loss: 0.3484910190105438
# Training Size: 65%, Epoch 40/50, Training Loss: 0.2681649226163115, Validation Loss: 0.339626411596934
# Training Size: 65%, Epoch 50/50, Training Loss: 0.26433544233441353, Validation Loss: 0.3248363663752874
# Accuracy: 0.859375
#  F1-Score: 0.8175605888281691
# Training Size: 65%
# Training Size: 65%, Epoch 10/50, Training Loss: 0.40418887031929834, Validation Loss: 0.42326120336850487
# Training Size: 65%, Epoch 20/50, Training Loss: 0.31325204244681765, Validation Loss: 0.3515202283859253
# Training Size: 65%, Epoch 30/50, Training Loss: 0.2772317257310663, Validation Loss: 0.3386903742949168
# Training Size: 65%, Epoch 40/50, Training Loss: 0.24556709027716092, Validation Loss: 0.3051314651966095
# Training Size: 65%, Epoch 50/50, Training Loss: 0.23804686005626405, Validation Loss: 0.3065080285072327
# Accuracy: 0.83984375
#  F1-Score: 0.7674932471040465
# Training Size: 67%
# Training Size: 67%, Epoch 10/50, Training Loss: 0.44637296836951684, Validation Loss: 0.4417980526174818
# Training Size: 67%, Epoch 20/50, Training Loss: 0.35198556040895396, Validation Loss: 0.4043872484139034
# Training Size: 67%, Epoch 30/50, Training Loss: 0.30085396252829455, Validation Loss: 0.3485072446720941
# Training Size: 67%, Epoch 40/50, Training Loss: 0.2677987902585802, Validation Loss: 0.3431108977113451
# Training Size: 67%, Epoch 50/50, Training Loss: 0.2501070627878452, Validation Loss: 0.31562541318791254
# Accuracy: 0.828125
#  F1-Score: 0.7665404040404041
# Training Size: 68%
# Training Size: 68%, Epoch 10/50, Training Loss: 0.39348334176787014, Validation Loss: 0.40184637691293446
# Training Size: 68%, Epoch 20/50, Training Loss: 0.30601626840131035, Validation Loss: 0.3494601398706436
# Training Size: 68%, Epoch 30/50, Training Loss: 0.2649091394810841, Validation Loss: 0.3197883239814213
# Training Size: 68%, Epoch 40/50, Training Loss: 0.23671016405368672, Validation Loss: 0.3066296268786703
# Training Size: 68%, Epoch 50/50, Training Loss: 0.2237146388867806, Validation Loss: 0.306920913713319
# Accuracy: 0.8515625
#  F1-Score: 0.8092264633499011
# Training Size: 69%
# Training Size: 69%, Epoch 10/50, Training Loss: 0.42670848246278437, Validation Loss: 0.4393608753497784
# Training Size: 69%, Epoch 20/50, Training Loss: 0.33488479153863315, Validation Loss: 0.3803843924632439
# Training Size: 69%, Epoch 30/50, Training Loss: 0.2795750195610112, Validation Loss: 0.358505707520705
# Training Size: 69%, Epoch 40/50, Training Loss: 0.25055975903724803, Validation Loss: 0.3393108042386862
# Training Size: 69%, Epoch 50/50, Training Loss: 0.21782014493284554, Validation Loss: 0.35769256261678845
# Accuracy: 0.84375
#  F1-Score: 0.7872308612440192
# Training Size: 70%
# Training Size: 70%, Epoch 10/50, Training Loss: 0.4050777028004328, Validation Loss: 0.4122773752762721
# Training Size: 70%, Epoch 20/50, Training Loss: 0.31207305391629536, Validation Loss: 0.36244014822519743
# Training Size: 70%, Epoch 30/50, Training Loss: 0.276192103823026, Validation Loss: 0.33133389628850496
# Training Size: 70%, Epoch 40/50, Training Loss: 0.2393637220064799, Validation Loss: 0.320975104203591
# Training Size: 70%, Epoch 50/50, Training Loss: 0.2205804909269015, Validation Loss: 0.3114908200043898
# Accuracy: 0.84765625
#  F1-Score: 0.797733264851909
# Training Size: 71%
# Training Size: 71%, Epoch 10/50, Training Loss: 0.4113927612702052, Validation Loss: 0.4381952446240645
# Training Size: 71%, Epoch 20/50, Training Loss: 0.3042712350686391, Validation Loss: 0.38472649684319127
# Training Size: 71%, Epoch 30/50, Training Loss: 0.26168167491753896, Validation Loss: 0.36404257783522975
# Training Size: 71%, Epoch 40/50, Training Loss: 0.23383832573890687, Validation Loss: 0.34806690307763904
# Training Size: 71%, Epoch 50/50, Training Loss: 0.22321036110321682, Validation Loss: 0.34858877612994266
# Accuracy: 0.8671875
#  F1-Score: 0.8176750263831104
# Training Size: 72%
# Training Size: 72%, Epoch 10/50, Training Loss: 0.3868005746795285, Validation Loss: 0.41797394057114917
# Training Size: 72%, Epoch 20/50, Training Loss: 0.2996498798170397, Validation Loss: 0.35655492047468823
# Training Size: 72%, Epoch 30/50, Training Loss: 0.2637059121362625, Validation Loss: 0.3275964359442393
# Training Size: 72%, Epoch 40/50, Training Loss: 0.2510022453723415, Validation Loss: 0.3232256720463435
# Training Size: 72%, Epoch 50/50, Training Loss: 0.21952164990286674, Validation Loss: 0.33141018574436504
# Accuracy: 0.8515625
#  F1-Score: 0.7896319222318626
# Training Size: 73%
# Training Size: 73%, Epoch 10/50, Training Loss: 0.3809925769605944, Validation Loss: 0.3941579709450404
# Training Size: 73%, Epoch 20/50, Training Loss: 0.2983503956948557, Validation Loss: 0.338290532430013
# Training Size: 73%, Epoch 30/50, Training Loss: 0.26377012556599033, Validation Loss: 0.30987878888845444
# Training Size: 73%, Epoch 40/50, Training Loss: 0.23749081790447235, Validation Loss: 0.31217821687459946
# Training Size: 73%, Epoch 50/50, Training Loss: 0.2156741205723055, Validation Loss: 0.3001418548325698
# Accuracy: 0.85546875
#  F1-Score: 0.795356590863963
# Training Size: 74%
# Training Size: 74%, Epoch 10/50, Training Loss: 0.3704097424784014, Validation Loss: 0.3982780629938299
# Training Size: 74%, Epoch 20/50, Training Loss: 0.2962083561766532, Validation Loss: 0.36596223982897674
# Training Size: 74%, Epoch 30/50, Training Loss: 0.2574969284957455, Validation Loss: 0.35433685237711127
# Training Size: 74%, Epoch 40/50, Training Loss: 0.22801992585582118, Validation Loss: 0.33651857619935815
# Training Size: 74%, Epoch 50/50, Training Loss: 0.20866472490372195, Validation Loss: 0.33653733947060327
# Accuracy: 0.84765625
#  F1-Score: 0.7937830530148684
# Training Size: 75%
# Training Size: 75%, Epoch 10/50, Training Loss: 0.3755858289077878, Validation Loss: 0.41412133791229944
# Training Size: 75%, Epoch 20/50, Training Loss: 0.2998816887848079, Validation Loss: 0.3624243682081049
# Training Size: 75%, Epoch 30/50, Training Loss: 0.2700436501763761, Validation Loss: 0.3476989540186795
# Training Size: 75%, Epoch 40/50, Training Loss: 0.2423880798742175, Validation Loss: 0.34633849832144653
# Training Size: 75%, Epoch 50/50, Training Loss: 0.22412773501127958, Validation Loss: 0.34265724501826544
# Accuracy: 0.8515625
#  F1-Score: 0.794333187387383
# Training Size: 76%
# Training Size: 76%, Epoch 10/50, Training Loss: 0.3788864118978381, Validation Loss: 0.41236219622872095
# Training Size: 76%, Epoch 20/50, Training Loss: 0.2875529769808054, Validation Loss: 0.34066039052876557
# Training Size: 76%, Epoch 30/50, Training Loss: 0.24974667141214013, Validation Loss: 0.32430694049054926
# Training Size: 76%, Epoch 40/50, Training Loss: 0.22952180821448565, Validation Loss: 0.2990863716060465
# Training Size: 76%, Epoch 50/50, Training Loss: 0.20396908978000283, Validation Loss: 0.31104254722595215
# Accuracy: 0.8515625
#  F1-Score: 0.8019030146243598
# Training Size: 77%
# Training Size: 77%, Epoch 10/50, Training Loss: 0.34444417736747046, Validation Loss: 0.3609654664993286
# Training Size: 77%, Epoch 20/50, Training Loss: 0.2785058012514403, Validation Loss: 0.31867330372333524
# Training Size: 77%, Epoch 30/50, Training Loss: 0.24277246630553043, Validation Loss: 0.29432978928089143
# Training Size: 77%, Epoch 40/50, Training Loss: 0.21897285318735873, Validation Loss: 0.2843921735882759
# Training Size: 77%, Epoch 50/50, Training Loss: 0.19738903212727923, Validation Loss: 0.2619719386100769
# Accuracy: 0.87890625
#  F1-Score: 0.8410472577053791
# Training Size: 78%
# Training Size: 78%, Epoch 10/50, Training Loss: 0.3575974946672266, Validation Loss: 0.36867893040180205
# Training Size: 78%, Epoch 20/50, Training Loss: 0.2783293696967038, Validation Loss: 0.3144133150577545
# Training Size: 78%, Epoch 30/50, Training Loss: 0.24088123711672696, Validation Loss: 0.28106361627578735
# Training Size: 78%, Epoch 40/50, Training Loss: 0.2130914009881742, Validation Loss: 0.2679964482784271
# Training Size: 78%, Epoch 50/50, Training Loss: 0.19836067972761212, Validation Loss: 0.2544457420706749
# Accuracy: 0.875
#  F1-Score: 0.8358924628663187
# Training Size: 79%
# Training Size: 79%, Epoch 10/50, Training Loss: 0.39997099427615895, Validation Loss: 0.3863549530506134
# Training Size: 79%, Epoch 20/50, Training Loss: 0.28835610212648616, Validation Loss: 0.31620605124367607
# Training Size: 79%, Epoch 30/50, Training Loss: 0.25582633386639986, Validation Loss: 0.27882323496871525
# Training Size: 79%, Epoch 40/50, Training Loss: 0.2211821999619989, Validation Loss: 0.27022874024179244
# Training Size: 79%, Epoch 50/50, Training Loss: 0.19812503665247383, Validation Loss: 0.2738095372915268
# Accuracy: 0.84765625
#  F1-Score: 0.8076288542496302
# Training Size: 80%
# Training Size: 80%, Epoch 10/50, Training Loss: 0.3455739231670604, Validation Loss: 0.34632401002777946
# Training Size: 80%, Epoch 20/50, Training Loss: 0.27602536625721874, Validation Loss: 0.29801783131228554
# Training Size: 80%, Epoch 30/50, Training Loss: 0.23905099314801834, Validation Loss: 0.2592865212096108
# Training Size: 80%, Epoch 40/50, Training Loss: 0.2115678064086858, Validation Loss: 0.2525242368380229
# Training Size: 80%, Epoch 50/50, Training Loss: 0.19412644930622158, Validation Loss: 0.25931769278314376
# Accuracy: 0.85546875
#  F1-Score: 0.8155030940412147
# Training Size: 81%
# Training Size: 81%, Epoch 10/50, Training Loss: 0.36880914078039284, Validation Loss: 0.3675208240747452
# Training Size: 81%, Epoch 20/50, Training Loss: 0.29377281665802, Validation Loss: 0.3062581308186054
# Training Size: 81%, Epoch 30/50, Training Loss: 0.2644939006251447, Validation Loss: 0.3105294220149517
# Training Size: 81%, Epoch 40/50, Training Loss: 0.23687127889955745, Validation Loss: 0.27270927652716637
# Training Size: 81%, Epoch 50/50, Training Loss: 0.2156454622745514, Validation Loss: 0.2717675808817148
# Accuracy: 0.859375
#  F1-Score: 0.8287072981366459
# Training Size: 82%
# Training Size: 82%, Epoch 10/50, Training Loss: 0.362618373973029, Validation Loss: 0.37121107801795006
# Training Size: 82%, Epoch 20/50, Training Loss: 0.2753021333898817, Validation Loss: 0.2937539927661419
# Training Size: 82%, Epoch 30/50, Training Loss: 0.23471515136105672, Validation Loss: 0.2771837506443262
# Training Size: 82%, Epoch 40/50, Training Loss: 0.20645264301981245, Validation Loss: 0.2599321939051151
# Training Size: 82%, Epoch 50/50, Training Loss: 0.18976474404335023, Validation Loss: 0.25790578685700893
# Accuracy: 0.85546875
#  F1-Score: 0.8048183382529887
# Training Size: 83%
# Training Size: 83%, Epoch 10/50, Training Loss: 0.3590878290789468, Validation Loss: 0.36724070087075233
# Training Size: 83%, Epoch 20/50, Training Loss: 0.28182110232966284, Validation Loss: 0.27783256582915783
# Training Size: 83%, Epoch 30/50, Training Loss: 0.24774594945566994, Validation Loss: 0.24562795646488667
# Training Size: 83%, Epoch 40/50, Training Loss: 0.21551732804094043, Validation Loss: 0.23360201250761747
# Training Size: 83%, Epoch 50/50, Training Loss: 0.1996352229799543, Validation Loss: 0.22494526766240597
# Accuracy: 0.87109375
#  F1-Score: 0.8209504380612375
# Training Size: 84%
# Training Size: 84%, Epoch 10/50, Training Loss: 0.3412281076113383, Validation Loss: 0.3630733106817518
# Training Size: 84%, Epoch 20/50, Training Loss: 0.2739029336306784, Validation Loss: 0.3087820453303201
# Training Size: 84%, Epoch 30/50, Training Loss: 0.23826007917523384, Validation Loss: 0.2768811881542206
# Training Size: 84%, Epoch 40/50, Training Loss: 0.22206294164061546, Validation Loss: 0.2640396569456373
# Training Size: 84%, Epoch 50/50, Training Loss: 0.19401033719380698, Validation Loss: 0.2567595158304487
# Accuracy: 0.890625
#  F1-Score: 0.8407339878447873
# Training Size: 85%
# Training Size: 85%, Epoch 10/50, Training Loss: 0.3557184934616089, Validation Loss: 0.3638037315436772
# Training Size: 85%, Epoch 20/50, Training Loss: 0.2804178169204129, Validation Loss: 0.3127145639487675
# Training Size: 85%, Epoch 30/50, Training Loss: 0.24563605462511381, Validation Loss: 0.29546789612088886
# Training Size: 85%, Epoch 40/50, Training Loss: 0.22267811000347137, Validation Loss: 0.2873555230242865
# Training Size: 85%, Epoch 50/50, Training Loss: 0.20128417511781058, Validation Loss: 0.29536119529179167
# Accuracy: 0.86328125
#  F1-Score: 0.8223875089076657
# Training Size: 86%
# Training Size: 86%, Epoch 10/50, Training Loss: 0.31913019013073707, Validation Loss: 0.329520250360171
# Training Size: 86%, Epoch 20/50, Training Loss: 0.2586326946814855, Validation Loss: 0.29022358854611713
# Training Size: 86%, Epoch 30/50, Training Loss: 0.22436128887865278, Validation Loss: 0.27222932626803714
# Training Size: 86%, Epoch 40/50, Training Loss: 0.20208260748121473, Validation Loss: 0.2781949018438657
# Training Size: 86%, Epoch 50/50, Training Loss: 0.18412160066266856, Validation Loss: 0.2719935302933057
# Accuracy: 0.87109375
#  F1-Score: 0.8206755658238137
# Training Size: 87%
# Training Size: 87%, Epoch 10/50, Training Loss: 0.3096275816898088, Validation Loss: 0.30596082905928296
# Training Size: 87%, Epoch 20/50, Training Loss: 0.2395107730014904, Validation Loss: 0.26039914786815643
# Training Size: 87%, Epoch 30/50, Training Loss: 0.19994776031455477, Validation Loss: 0.24073636283477148
# Training Size: 87%, Epoch 40/50, Training Loss: 0.17498101455134316, Validation Loss: 0.21952632317940393
# Training Size: 87%, Epoch 50/50, Training Loss: 0.15443619703118866, Validation Loss: 0.22210387140512466
# Accuracy: 0.8828125
#  F1-Score: 0.8433940927299561
# Training Size: 88%
# Training Size: 88%, Epoch 10/50, Training Loss: 0.3216336031217833, Validation Loss: 0.30082713067531586
# Training Size: 88%, Epoch 20/50, Training Loss: 0.2623330612440367, Validation Loss: 0.26716036597887677
# Training Size: 88%, Epoch 30/50, Training Loss: 0.2308484646114143, Validation Loss: 0.23237715909878412
# Training Size: 88%, Epoch 40/50, Training Loss: 0.20683234023886757, Validation Loss: 0.23957043389479318
# Training Size: 88%, Epoch 50/50, Training Loss: 0.19045088379769712, Validation Loss: 0.2298614184061686
# Accuracy: 0.875
#  F1-Score: 0.8254533755998893
# Training Size: 89%
# Training Size: 89%, Epoch 10/50, Training Loss: 0.32046609175832647, Validation Loss: 0.3196443855762482
# Training Size: 89%, Epoch 20/50, Training Loss: 0.25370753242781285, Validation Loss: 0.2784182369709015
# Training Size: 89%, Epoch 30/50, Training Loss: 0.2225403907267671, Validation Loss: 0.2663606464862823
# Training Size: 89%, Epoch 40/50, Training Loss: 0.19442548308717578, Validation Loss: 0.24731417894363403
# Training Size: 89%, Epoch 50/50, Training Loss: 0.17574593718898923, Validation Loss: 0.23892900645732879
# Accuracy: 0.88671875
#  F1-Score: 0.8533774196817675
# Training Size: 90%
# Training Size: 90%, Epoch 10/50, Training Loss: 0.3257284736947009, Validation Loss: 0.2978146255016327
# Training Size: 90%, Epoch 20/50, Training Loss: 0.2663771047403938, Validation Loss: 0.2477926105260849
# Training Size: 90%, Epoch 30/50, Training Loss: 0.22121861733888326, Validation Loss: 0.2204302355647087
# Training Size: 90%, Epoch 40/50, Training Loss: 0.19483432330583272, Validation Loss: 0.22349091172218322
# Training Size: 90%, Epoch 50/50, Training Loss: 0.17678171572716614, Validation Loss: 0.20228064358234404
# Accuracy: 0.86328125
#  F1-Score: 0.8075274016763379
# Training Size: 91%
# Training Size: 91%, Epoch 10/50, Training Loss: 0.3232023998712882, Validation Loss: 0.3307590112090111
# Training Size: 91%, Epoch 20/50, Training Loss: 0.26451197763284046, Validation Loss: 0.2854684293270111
# Training Size: 91%, Epoch 30/50, Training Loss: 0.2217966600870475, Validation Loss: 0.24466584622859955
# Training Size: 91%, Epoch 40/50, Training Loss: 0.19858855505784354, Validation Loss: 0.23377560451626778
# Training Size: 91%, Epoch 50/50, Training Loss: 0.178797329752109, Validation Loss: 0.2506782226264477
# Accuracy: 0.8984375
#  F1-Score: 0.8606307344119991
# Training Size: 92%
# Training Size: 92%, Epoch 10/50, Training Loss: 0.30239715025975156, Validation Loss: 0.32669059932231903
# Training Size: 92%, Epoch 20/50, Training Loss: 0.24166811620577788, Validation Loss: 0.2729479782283306
# Training Size: 92%, Epoch 30/50, Training Loss: 0.20695679042583856, Validation Loss: 0.25459664687514305
# Training Size: 92%, Epoch 40/50, Training Loss: 0.18550655169364733, Validation Loss: 0.23815201222896576
# Training Size: 92%, Epoch 50/50, Training Loss: 0.1682704052863977, Validation Loss: 0.21733395755290985
# Accuracy: 0.890625
#  F1-Score: 0.8557928997470172
# Training Size: 93%
# Training Size: 93%, Epoch 10/50, Training Loss: 0.3132942979916548, Validation Loss: 0.3162799080212911
# Training Size: 93%, Epoch 20/50, Training Loss: 0.24614618795040327, Validation Loss: 0.2712222586075465
# Training Size: 93%, Epoch 30/50, Training Loss: 0.21284327216637441, Validation Loss: 0.2462349385023117
# Training Size: 93%, Epoch 40/50, Training Loss: 0.18601179180236962, Validation Loss: 0.2490988920132319
# Training Size: 93%, Epoch 50/50, Training Loss: 0.16863833730801558, Validation Loss: 0.22933444877465567
# Accuracy: 0.8828125
#  F1-Score: 0.837890499194847
# Training Size: 94%
# Training Size: 94%, Epoch 10/50, Training Loss: 0.3204708777368069, Validation Loss: 0.321216344833374
# Training Size: 94%, Epoch 20/50, Training Loss: 0.2473503727465868, Validation Loss: 0.256642351547877
# Training Size: 94%, Epoch 30/50, Training Loss: 0.215225750207901, Validation Loss: 0.24664892256259918
# Training Size: 94%, Epoch 40/50, Training Loss: 0.18927939385175704, Validation Loss: 0.24210038284460703
# Training Size: 94%, Epoch 50/50, Training Loss: 0.1765682462602854, Validation Loss: 0.24411561588446298
# Accuracy: 0.87109375
#  F1-Score: 0.840118793062485
# Training Size: 95%
# Training Size: 95%, Epoch 10/50, Training Loss: 0.30469056144356726, Validation Loss: 0.3365563253561656
# Training Size: 95%, Epoch 20/50, Training Loss: 0.24976716227829457, Validation Loss: 0.27044034004211426
# Training Size: 95%, Epoch 30/50, Training Loss: 0.21709384992718697, Validation Loss: 0.2616877357165019
# Training Size: 95%, Epoch 40/50, Training Loss: 0.19188577495515347, Validation Loss: 0.23302414019902548
# Training Size: 95%, Epoch 50/50, Training Loss: 0.18399937283247708, Validation Loss: 0.20718145370483398
# Accuracy: 0.875
#  F1-Score: 0.826118736116093

# %%
# Print the results for different training sizes
for result in results:
    print(f"Training Size: {result['Training Size']}%, "
          f"Multi-label Validation Accuracy: {result['Multi-label Validation Accuracy'] * 100:.2f}%, "
          f"F1 Score: {result['F1 Score']:.2f}")
# Out:
# Training Size: 5%, Multi-label Validation Accuracy: 59.38%, F1 Score: 0.14
# Training Size: 6%, Multi-label Validation Accuracy: 57.81%, F1 Score: 0.14
# Training Size: 6%, Multi-label Validation Accuracy: 57.81%, F1 Score: 0.14
# Training Size: 7%, Multi-label Validation Accuracy: 45.31%, F1 Score: 0.24
# Training Size: 8%, Multi-label Validation Accuracy: 57.81%, F1 Score: 0.14
# Training Size: 9%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 10%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 12%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 13%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 14%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 15%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 16%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 17%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 18%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 18%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 19%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 20%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 21%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 23%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 24%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 25%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 26%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.00
# Training Size: 27%, Multi-label Validation Accuracy: 75.39%, F1 Score: 0.59
# Training Size: 28%, Multi-label Validation Accuracy: 75.78%, F1 Score: 0.59
# Training Size: 29%, Multi-label Validation Accuracy: 77.73%, F1 Score: 0.62
# Training Size: 30%, Multi-label Validation Accuracy: 80.86%, F1 Score: 0.72
# Training Size: 31%, Multi-label Validation Accuracy: 78.12%, F1 Score: 0.69
# Training Size: 31%, Multi-label Validation Accuracy: 78.12%, F1 Score: 0.67
# Training Size: 32%, Multi-label Validation Accuracy: 79.69%, F1 Score: 0.70
# Training Size: 34%, Multi-label Validation Accuracy: 80.47%, F1 Score: 0.73
# Training Size: 35%, Multi-label Validation Accuracy: 79.30%, F1 Score: 0.70
# Training Size: 36%, Multi-label Validation Accuracy: 79.69%, F1 Score: 0.70
# Training Size: 37%, Multi-label Validation Accuracy: 79.30%, F1 Score: 0.68
# Training Size: 38%, Multi-label Validation Accuracy: 78.91%, F1 Score: 0.69
# Training Size: 39%, Multi-label Validation Accuracy: 78.12%, F1 Score: 0.69
# Training Size: 40%, Multi-label Validation Accuracy: 78.91%, F1 Score: 0.66
# Training Size: 41%, Multi-label Validation Accuracy: 80.08%, F1 Score: 0.71
# Training Size: 42%, Multi-label Validation Accuracy: 82.03%, F1 Score: 0.72
# Training Size: 43%, Multi-label Validation Accuracy: 83.20%, F1 Score: 0.76
# Training Size: 43%, Multi-label Validation Accuracy: 80.47%, F1 Score: 0.69
# Training Size: 44%, Multi-label Validation Accuracy: 80.08%, F1 Score: 0.75
# Training Size: 46%, Multi-label Validation Accuracy: 82.81%, F1 Score: 0.76
# Training Size: 47%, Multi-label Validation Accuracy: 84.38%, F1 Score: 0.78
# Training Size: 48%, Multi-label Validation Accuracy: 82.03%, F1 Score: 0.75
# Training Size: 49%, Multi-label Validation Accuracy: 83.59%, F1 Score: 0.79
# Training Size: 50%, Multi-label Validation Accuracy: 79.30%, F1 Score: 0.74
# Training Size: 51%, Multi-label Validation Accuracy: 82.81%, F1 Score: 0.77
# Training Size: 52%, Multi-label Validation Accuracy: 83.20%, F1 Score: 0.75
# Training Size: 53%, Multi-label Validation Accuracy: 83.59%, F1 Score: 0.75
# Training Size: 54%, Multi-label Validation Accuracy: 82.81%, F1 Score: 0.77
# Training Size: 55%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.79
# Training Size: 56%, Multi-label Validation Accuracy: 82.03%, F1 Score: 0.77
# Training Size: 57%, Multi-label Validation Accuracy: 83.20%, F1 Score: 0.75
# Training Size: 58%, Multi-label Validation Accuracy: 84.77%, F1 Score: 0.79
# Training Size: 59%, Multi-label Validation Accuracy: 83.59%, F1 Score: 0.77
# Training Size: 60%, Multi-label Validation Accuracy: 81.64%, F1 Score: 0.77
# Training Size: 61%, Multi-label Validation Accuracy: 87.50%, F1 Score: 0.84
# Training Size: 62%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.76
# Training Size: 63%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.83
# Training Size: 64%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.79
# Training Size: 65%, Multi-label Validation Accuracy: 85.94%, F1 Score: 0.82
# Training Size: 65%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.77
# Training Size: 67%, Multi-label Validation Accuracy: 82.81%, F1 Score: 0.77
# Training Size: 68%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.81
# Training Size: 69%, Multi-label Validation Accuracy: 84.38%, F1 Score: 0.79
# Training Size: 70%, Multi-label Validation Accuracy: 84.77%, F1 Score: 0.80
# Training Size: 71%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.82
# Training Size: 72%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.79
# Training Size: 73%, Multi-label Validation Accuracy: 85.55%, F1 Score: 0.80
# Training Size: 74%, Multi-label Validation Accuracy: 84.77%, F1 Score: 0.79
# Training Size: 75%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.79
# Training Size: 76%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.80
# Training Size: 77%, Multi-label Validation Accuracy: 87.89%, F1 Score: 0.84
# Training Size: 78%, Multi-label Validation Accuracy: 87.50%, F1 Score: 0.84
# Training Size: 79%, Multi-label Validation Accuracy: 84.77%, F1 Score: 0.81
# Training Size: 80%, Multi-label Validation Accuracy: 85.55%, F1 Score: 0.82
# Training Size: 81%, Multi-label Validation Accuracy: 85.94%, F1 Score: 0.83
# Training Size: 82%, Multi-label Validation Accuracy: 85.55%, F1 Score: 0.80
# Training Size: 83%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.82
# Training Size: 84%, Multi-label Validation Accuracy: 89.06%, F1 Score: 0.84
# Training Size: 85%, Multi-label Validation Accuracy: 86.33%, F1 Score: 0.82
# Training Size: 86%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.82
# Training Size: 87%, Multi-label Validation Accuracy: 88.28%, F1 Score: 0.84
# Training Size: 88%, Multi-label Validation Accuracy: 87.50%, F1 Score: 0.83
# Training Size: 89%, Multi-label Validation Accuracy: 88.67%, F1 Score: 0.85
# Training Size: 90%, Multi-label Validation Accuracy: 86.33%, F1 Score: 0.81
# Training Size: 91%, Multi-label Validation Accuracy: 89.84%, F1 Score: 0.86
# Training Size: 92%, Multi-label Validation Accuracy: 89.06%, F1 Score: 0.86
# Training Size: 93%, Multi-label Validation Accuracy: 88.28%, F1 Score: 0.84
# Training Size: 94%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.84
# Training Size: 95%, Multi-label Validation Accuracy: 87.50%, F1 Score: 0.83

# %%
# Extract data for plotting
training_sizes = [result['Training Size'] for result in results]
accuracies = [result['Multi-label Validation Accuracy'] * 100 for result in results]
f1_scores = [result['F1 Score'] *100 for result in results]

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(training_sizes, accuracies, label='Accuracy', marker='o', linestyle='-', color='b')
plt.plot(training_sizes, f1_scores, label='F1 Score', marker='o', linestyle='-', color='r')

# Set axis labels and legend
plt.xlabel('Training Size (%)')
plt.ylabel('Metrics (%)')
plt.title('Accuracy and F1 Score vs. Training Size')
plt.legend()

# Show the plot
plt.grid()
plt.show()

# %% [markdown]
# # Thank You
