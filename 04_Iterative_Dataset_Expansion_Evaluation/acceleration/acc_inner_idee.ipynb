# %%
#---import libraries relating to data manipulation, visualization---------------------------------------------------
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option("max_colwidth", None)

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import json

#-------import libraries to evaluate the deep learning model---------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, multilabel_confusion_matrix

import warnings
warnings.filterwarnings('ignore')

#------ import Deep Learning Libraries-------#

import torch
import torch.nn as nn
import torch.optim as optim
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
import pickle

import sys
sys.path.append('../../src')  # Add the 'src' directory to the path

#### Import Data Loading and Processing Functions
from multimodal.helper_functions import  reproducible_comp, get_final_df

#### Import Model Architecture
from multimodal.model_architecture import Generic1DCNN
reproducible_comp()
# Out:
# 2023-11-06 15:17:35.229007: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-06 15:17:35.229057: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-06 15:17:35.229079: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-06 15:17:35.235771: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-06 15:17:36.013856: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
file_path = "../../data/processed_data/acc_inner.pkl"
with open(file_path, 'rb') as picklefile:
    data = pickle.load(picklefile)

features_acc_inner, category_acc_inner, category_names, df_acc_inner = get_final_df(data, is_acc_data=1, is_multilabel=1)

labels = category_acc_inner.copy()
features=features_acc_inner.copy()
print("Features Shape: ", features.shape)
print("Labels Shape: ", labels.shape)
# Out:
# Features Shape:  (1350, 3)
# Labels Shape:  (1350, 4)

# %%
max_length = 500

for i in range (len(features)):
    if(len(features[i][0]<max_length)):
        features[i][0]=np.pad(features[i][0], (0,max_length-len(features[i][0])), 'constant', constant_values=(0))
        
    if(len(features[i][1]<max_length)):
        features[i][1]=np.pad(features[i][1], (0,max_length-len(features[i][1])), 'constant', constant_values=(0))
    
    if(len(features[i][2]<max_length)):
        features[i][2]=np.pad(features[i][2], (0,max_length-len(features[i][2])), 'constant', constant_values=(0))

# %%
feat= np.zeros(len(features)*3*max_length).reshape(-1, 3*max_length)
for i in range(len(features)):
    feat[i]= np.concatenate((features[i][0],features[i][1], features[i][2]), axis=None)
    

print("Updated Features Shape: ", feat.shape)
# Out:
# Updated Features Shape:  (1350, 1500)

# %%
# Specify the path where you want to save the JSON file
config_file_path = "../../02_Optuna_Runs/acceleration/best_configs/acc_inner_best_configs.json"

# Load the saved configuration
with open(config_file_path, "r") as config_file:
    best_configs = json.load(config_file)

best_params = best_configs["best_params"]
print(best_params)
# Out:
# {'lr': 0.00018137907646630452, 'dropout_prob': 0.3524356687822107, 'hidden_channels': 219, 'n_layers': 4, 'kernel_size': 9, 'stride': 2, 'padding': 6, 'pooling_type': 'avg', 'use_batch_norm': True}

# %%
X_train = feat.reshape(-1, 1, feat.shape[1])
y_train = labels.copy()

print(X_train.shape)
print(y_train.shape)
# Out:
# (1350, 1, 1500)
# (1350, 4)

# %%
# Define the start, end, and interval
start = 0.95
end = 0.04
interval = -0.01

validation_sizes = [round(start + i * interval, 2) for i in range(int((end - start) / interval) + 1)]

# %%
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import f1_score

def multi_label_accuracy(y_true, y_pred):
    # Check if each label is correctly predicted
    label_accuracies = np.mean(y_true == y_pred, axis=0)
    # Compute the overall accuracy by taking the mean of label accuracies
    accuracy = np.mean(label_accuracies)
    return accuracy

# Convert your data to PyTorch tensors
x_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)

input_channels = 1
num_classes = 4
n_layers = best_params["n_layers"]
kernel_size = best_params["kernel_size"]
stride = best_params["stride"]
padding = best_params["padding"]
hidden_channels = best_params["hidden_channels"]
dropout_prob = best_params["dropout_prob"]
pooling_type = best_params["pooling_type"]
use_batch_norm = best_params["use_batch_norm"]

# Define your loss function and optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Lists to store training and validation loss values and results for different training sizes
results = []

num_epochs = 50

for validation_size in validation_sizes:
    try:
        print(f"Training Size: {int((1-validation_size) * 100)}%")
        train_losses_iter = []  # Store training losses for this training size
        valid_losses_iter = []  # Store validation losses for this training size

        # Split the data into training and validation sets for this training size
        # Split the data into training and validation sets
        x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(
            x_train, y_train, test_size=validation_size, random_state=42
        )

        train_dataset = TensorDataset(x_train_split, y_train_split)
        valid_dataset = TensorDataset(x_valid_split, y_valid_split)

        train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
        valid_loader = DataLoader(valid_dataset, batch_size=64, shuffle=False)

        model = Generic1DCNN(input_channels, num_classes, n_layers, kernel_size, stride, padding,
                             hidden_channels, dropout_prob, pooling_type, use_batch_norm).to(device)

        criterion = nn.BCEWithLogitsLoss()
        optimizer = optim.Adam(model.parameters(), lr=best_params["lr"])

        model.train()
        for epoch in range(num_epochs):
            running_loss = 0.0
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels.float())
                loss.backward()
                optimizer.step()

                running_loss += loss.item()

            train_losses_iter.append(running_loss / len(train_loader))

            # Validation loss calculation (similar to training loop)
            model.eval()
            valid_loss = 0.0
            with torch.no_grad():
                for inputs_valid, labels_valid in valid_loader:
                    inputs_valid, labels_valid = inputs_valid.to(device), labels_valid.to(device)
                    outputs_valid = model(inputs_valid)
                    loss_valid = criterion(outputs_valid, labels_valid.float())
                    valid_loss += loss_valid.item()

            valid_losses_iter.append(valid_loss / len(valid_loader))

            if (epoch + 1) % 10 == 0:
                print(f"Training Size: {int((1-validation_size) * 100)}%, Epoch {epoch + 1}/{num_epochs}, "
                      f"Training Loss: {running_loss / len(train_loader)}, Validation Loss: {valid_loss / len(valid_loader)}")

        # Evaluation on the validation set for this training size
        model.eval()
        y_true_valid = []
        y_pred_valid = []

        with torch.no_grad():
            for inputs, labels in valid_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                labels = labels.int()
                outputs = model(inputs)
                predicted = (outputs > 0).int()
                y_true_valid.append(labels.cpu().numpy())
                y_pred_valid.append(predicted.cpu().numpy())

        # Convert lists to NumPy arrays for calculations
        y_true_valid = np.array(y_true_valid[0]).reshape(-1, 4)
        y_pred_valid = np.array(y_pred_valid[0]).reshape(-1, 4)

        accuracy = multi_label_accuracy(y_true_valid, y_pred_valid)
        f1 = f1_score(y_true_valid, y_pred_valid, average='macro')

        results.append({
            "Training Size": int((1-validation_size) * 100),
            "Multi-label Validation Accuracy": accuracy,
            "F1 Score": f1
        })
        print(f"Accuracy: {accuracy}\n F1-Score: {f1}")
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# Training Size: 5%
# Training Size: 5%, Epoch 10/50, Training Loss: 0.6982832849025726, Validation Loss: 0.6944166932787214
# Training Size: 5%, Epoch 20/50, Training Loss: 0.6882658004760742, Validation Loss: 0.6862129171689352
# Training Size: 5%, Epoch 30/50, Training Loss: 0.6648513376712799, Validation Loss: 0.6526587605476379
# Training Size: 5%, Epoch 40/50, Training Loss: 0.6720427572727203, Validation Loss: 0.6283790923300243
# Training Size: 5%, Epoch 50/50, Training Loss: 0.6347682178020477, Validation Loss: 0.6374031078247797
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 6%
# Training Size: 6%, Epoch 10/50, Training Loss: 0.6937796771526337, Validation Loss: 0.691432437300682
# Training Size: 6%, Epoch 20/50, Training Loss: 0.6813821494579315, Validation Loss: 0.6807706207036972
# Training Size: 6%, Epoch 30/50, Training Loss: 0.6431799829006195, Validation Loss: 0.640925508737564
# Training Size: 6%, Epoch 40/50, Training Loss: 0.6446841359138489, Validation Loss: 0.6302250981330871
# Training Size: 6%, Epoch 50/50, Training Loss: 0.6216928362846375, Validation Loss: 0.6299775660037994
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 6%
# Training Size: 6%, Epoch 10/50, Training Loss: 0.6840539276599884, Validation Loss: 0.6848120152950287
# Training Size: 6%, Epoch 20/50, Training Loss: 0.6778889298439026, Validation Loss: 0.6791450500488281
# Training Size: 6%, Epoch 30/50, Training Loss: 0.658574253320694, Validation Loss: 0.6564723640680313
# Training Size: 6%, Epoch 40/50, Training Loss: 0.6378419399261475, Validation Loss: 0.6292576432228089
# Training Size: 6%, Epoch 50/50, Training Loss: 0.6334164440631866, Validation Loss: 0.6304903775453568
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 7%
# Training Size: 7%, Epoch 10/50, Training Loss: 0.6885670125484467, Validation Loss: 0.6876212179660797
# Training Size: 7%, Epoch 20/50, Training Loss: 0.6758719086647034, Validation Loss: 0.6723265051841736
# Training Size: 7%, Epoch 30/50, Training Loss: 0.631845623254776, Validation Loss: 0.6310119211673737
# Training Size: 7%, Epoch 40/50, Training Loss: 0.63193479180336, Validation Loss: 0.6311841577291488
# Training Size: 7%, Epoch 50/50, Training Loss: 0.6292845606803894, Validation Loss: 0.6291363835334778
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 8%
# Training Size: 8%, Epoch 10/50, Training Loss: 0.6904731094837189, Validation Loss: 0.6890780299901962
# Training Size: 8%, Epoch 20/50, Training Loss: 0.6602910459041595, Validation Loss: 0.6515517890453338
# Training Size: 8%, Epoch 30/50, Training Loss: 0.6308423578739166, Validation Loss: 0.6322249352931977
# Training Size: 8%, Epoch 40/50, Training Loss: 0.629713624715805, Validation Loss: 0.6292259067296981
# Training Size: 8%, Epoch 50/50, Training Loss: 0.6301282346248627, Validation Loss: 0.6294885665178299
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 9%
# Training Size: 9%, Epoch 10/50, Training Loss: 0.6832883556683859, Validation Loss: 0.6850195715301916
# Training Size: 9%, Epoch 20/50, Training Loss: 0.6754077474276224, Validation Loss: 0.6772876068165428
# Training Size: 9%, Epoch 30/50, Training Loss: 0.6623219052950541, Validation Loss: 0.6579011835550007
# Training Size: 9%, Epoch 40/50, Training Loss: 0.6286623477935791, Validation Loss: 0.6379113165955794
# Training Size: 9%, Epoch 50/50, Training Loss: 0.6193027297655741, Validation Loss: 0.6346618062571475
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 10%
# Training Size: 10%, Epoch 10/50, Training Loss: 0.6881970763206482, Validation Loss: 0.6874192231579831
# Training Size: 10%, Epoch 20/50, Training Loss: 0.6654684543609619, Validation Loss: 0.6603250189831382
# Training Size: 10%, Epoch 30/50, Training Loss: 0.6322294274965922, Validation Loss: 0.6302296676133808
# Training Size: 10%, Epoch 40/50, Training Loss: 0.6257852713267008, Validation Loss: 0.6297166096536737
# Training Size: 10%, Epoch 50/50, Training Loss: 0.6303590734799703, Validation Loss: 0.6297403573989868
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 12%
# Training Size: 12%, Epoch 10/50, Training Loss: 0.6912913719813029, Validation Loss: 0.690193584090785
# Training Size: 12%, Epoch 20/50, Training Loss: 0.6607295870780945, Validation Loss: 0.6535811800705759
# Training Size: 12%, Epoch 30/50, Training Loss: 0.6298128366470337, Validation Loss: 0.6299319298643815
# Training Size: 12%, Epoch 40/50, Training Loss: 0.6280697186787924, Validation Loss: 0.6305030772560521
# Training Size: 12%, Epoch 50/50, Training Loss: 0.6266699433326721, Validation Loss: 0.6277082123254475
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 13%
# Training Size: 13%, Epoch 10/50, Training Loss: 0.6814994812011719, Validation Loss: 0.6802161053607338
# Training Size: 13%, Epoch 20/50, Training Loss: 0.6350269516309103, Validation Loss: 0.632257154113368
# Training Size: 13%, Epoch 30/50, Training Loss: 0.6332267920176188, Validation Loss: 0.6293348481780604
# Training Size: 13%, Epoch 40/50, Training Loss: 0.6327527364095052, Validation Loss: 0.6282134401170831
# Training Size: 13%, Epoch 50/50, Training Loss: 0.629737138748169, Validation Loss: 0.6264398882263585
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 14%
# Training Size: 14%, Epoch 10/50, Training Loss: 0.6789192159970602, Validation Loss: 0.6763938665390015
# Training Size: 14%, Epoch 20/50, Training Loss: 0.6361519495646158, Validation Loss: 0.6289828262831035
# Training Size: 14%, Epoch 30/50, Training Loss: 0.6316216389338175, Validation Loss: 0.6286897816156086
# Training Size: 14%, Epoch 40/50, Training Loss: 0.6306458314259847, Validation Loss: 0.6273725754336307
# Training Size: 14%, Epoch 50/50, Training Loss: 0.6277634302775065, Validation Loss: 0.6244238646406877
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 15%
# Training Size: 15%, Epoch 10/50, Training Loss: 0.673628032207489, Validation Loss: 0.6713249153561063
# Training Size: 15%, Epoch 20/50, Training Loss: 0.6455364227294922, Validation Loss: 0.6339911354912652
# Training Size: 15%, Epoch 30/50, Training Loss: 0.635016143321991, Validation Loss: 0.6292051209343804
# Training Size: 15%, Epoch 40/50, Training Loss: 0.6336537748575211, Validation Loss: 0.6281462179289924
# Training Size: 15%, Epoch 50/50, Training Loss: 0.6255873143672943, Validation Loss: 0.624917619758182
# Accuracy: 0.6328125
#  F1-Score: 0.0
# Training Size: 16%
# Training Size: 16%, Epoch 10/50, Training Loss: 0.6794361621141434, Validation Loss: 0.6775144305494096
# Training Size: 16%, Epoch 20/50, Training Loss: 0.6330539137125015, Validation Loss: 0.6288954185114967
# Training Size: 16%, Epoch 30/50, Training Loss: 0.6346124857664108, Validation Loss: 0.6269891725646125
# Training Size: 16%, Epoch 40/50, Training Loss: 0.6206298917531967, Validation Loss: 0.6218178437815772
# Training Size: 16%, Epoch 50/50, Training Loss: 0.5834178030490875, Validation Loss: 0.5694215397040049
# Accuracy: 0.67578125
#  F1-Score: 0.18831168831168832
# Training Size: 17%
# Training Size: 17%, Epoch 10/50, Training Loss: 0.677509143948555, Validation Loss: 0.6753707329432169
# Training Size: 17%, Epoch 20/50, Training Loss: 0.6406015157699585, Validation Loss: 0.6327777670489417
# Training Size: 17%, Epoch 30/50, Training Loss: 0.6314345449209213, Validation Loss: 0.6282015807098813
# Training Size: 17%, Epoch 40/50, Training Loss: 0.6291739046573639, Validation Loss: 0.623106900188658
# Training Size: 17%, Epoch 50/50, Training Loss: 0.5889875590801239, Validation Loss: 0.596089588271247
# Accuracy: 0.640625
#  F1-Score: 0.045454545454545456
# Training Size: 18%
# Training Size: 18%, Epoch 10/50, Training Loss: 0.6722116619348526, Validation Loss: 0.6686791181564331
# Training Size: 18%, Epoch 20/50, Training Loss: 0.636172279715538, Validation Loss: 0.6282593376106687
# Training Size: 18%, Epoch 30/50, Training Loss: 0.6347676068544388, Validation Loss: 0.6277279754479727
# Training Size: 18%, Epoch 40/50, Training Loss: 0.6325177997350693, Validation Loss: 0.6250559356477525
# Training Size: 18%, Epoch 50/50, Training Loss: 0.616274505853653, Validation Loss: 0.6036263240708245
# Accuracy: 0.63671875
#  F1-Score: 0.016666666666666666
# Training Size: 18%
# Training Size: 18%, Epoch 10/50, Training Loss: 0.673111155629158, Validation Loss: 0.6695699161953397
# Training Size: 18%, Epoch 20/50, Training Loss: 0.6357237994670868, Validation Loss: 0.6281670696205564
# Training Size: 18%, Epoch 30/50, Training Loss: 0.6288736164569855, Validation Loss: 0.6210676100518968
# Training Size: 18%, Epoch 40/50, Training Loss: 0.5657561868429184, Validation Loss: 0.5568210383256277
# Training Size: 18%, Epoch 50/50, Training Loss: 0.4364950731396675, Validation Loss: 0.45432071056630874
# Accuracy: 0.7265625
#  F1-Score: 0.34392712550607285
# Training Size: 19%
# Training Size: 19%, Epoch 10/50, Training Loss: 0.6727270007133483, Validation Loss: 0.6702204977764803
# Training Size: 19%, Epoch 20/50, Training Loss: 0.6317825078964233, Validation Loss: 0.6290018313071307
# Training Size: 19%, Epoch 30/50, Training Loss: 0.63727205991745, Validation Loss: 0.6263952991541695
# Training Size: 19%, Epoch 40/50, Training Loss: 0.6336975455284118, Validation Loss: 0.620838768341962
# Training Size: 19%, Epoch 50/50, Training Loss: 0.5663569927215576, Validation Loss: 0.5518145070356482
# Accuracy: 0.69140625
#  F1-Score: 0.24893162393162396
# Training Size: 20%
# Training Size: 20%, Epoch 10/50, Training Loss: 0.6656603693962098, Validation Loss: 0.6604190503849703
# Training Size: 20%, Epoch 20/50, Training Loss: 0.6365878343582153, Validation Loss: 0.6285134027985966
# Training Size: 20%, Epoch 30/50, Training Loss: 0.6352278351783752, Validation Loss: 0.6236595125759349
# Training Size: 20%, Epoch 40/50, Training Loss: 0.592420756816864, Validation Loss: 0.5764268040657043
# Training Size: 20%, Epoch 50/50, Training Loss: 0.43652879595756533, Validation Loss: 0.44236600223709555
# Accuracy: 0.76171875
#  F1-Score: 0.5747560975609756
# Training Size: 21%
# Training Size: 21%, Epoch 10/50, Training Loss: 0.6557661294937134, Validation Loss: 0.6505308782353121
# Training Size: 21%, Epoch 20/50, Training Loss: 0.6319557666778565, Validation Loss: 0.6260628069148344
# Training Size: 21%, Epoch 30/50, Training Loss: 0.6252650380134582, Validation Loss: 0.61537485964158
# Training Size: 21%, Epoch 40/50, Training Loss: 0.49868729114532473, Validation Loss: 0.4938800212214975
# Training Size: 21%, Epoch 50/50, Training Loss: 0.4097788393497467, Validation Loss: 0.43844613432884216
# Accuracy: 0.74609375
#  F1-Score: 0.5607570388058193
# Training Size: 23%
# Training Size: 23%, Epoch 10/50, Training Loss: 0.6563549399375915, Validation Loss: 0.6487888062701506
# Training Size: 23%, Epoch 20/50, Training Loss: 0.634213650226593, Validation Loss: 0.6247887506204493
# Training Size: 23%, Epoch 30/50, Training Loss: 0.6194282293319702, Validation Loss: 0.6060436052434585
# Training Size: 23%, Epoch 40/50, Training Loss: 0.47881056666374205, Validation Loss: 0.4749166439561283
# Training Size: 23%, Epoch 50/50, Training Loss: 0.3883443534374237, Validation Loss: 0.4304937404744765
# Accuracy: 0.74609375
#  F1-Score: 0.5705849745663232
# Training Size: 24%
# Training Size: 24%, Epoch 10/50, Training Loss: 0.6638523638248444, Validation Loss: 0.659835976712844
# Training Size: 24%, Epoch 20/50, Training Loss: 0.6347256998221079, Validation Loss: 0.6287472458446727
# Training Size: 24%, Epoch 30/50, Training Loss: 0.6351242959499359, Validation Loss: 0.6281236410140991
# Training Size: 24%, Epoch 40/50, Training Loss: 0.627271701892217, Validation Loss: 0.6232477987513823
# Training Size: 24%, Epoch 50/50, Training Loss: 0.572135736544927, Validation Loss: 0.5396639880012063
# Accuracy: 0.671875
#  F1-Score: 0.1935483870967742
# Training Size: 25%
# Training Size: 25%, Epoch 10/50, Training Loss: 0.64930592974027, Validation Loss: 0.6414037346839905
# Training Size: 25%, Epoch 20/50, Training Loss: 0.6299118200937907, Validation Loss: 0.6240421757102013
# Training Size: 25%, Epoch 30/50, Training Loss: 0.5879526635011038, Validation Loss: 0.5773719921708107
# Training Size: 25%, Epoch 40/50, Training Loss: 0.4154234131177266, Validation Loss: 0.4274994842708111
# Training Size: 25%, Epoch 50/50, Training Loss: 0.40417764087518054, Validation Loss: 0.41353278793394566
# Accuracy: 0.7890625
#  F1-Score: 0.6488284202569917
# Training Size: 26%
# Training Size: 26%, Epoch 10/50, Training Loss: 0.6488981743653616, Validation Loss: 0.6439496725797653
# Training Size: 26%, Epoch 20/50, Training Loss: 0.6298070649305979, Validation Loss: 0.6253143027424812
# Training Size: 26%, Epoch 30/50, Training Loss: 0.5966089765230814, Validation Loss: 0.584033690392971
# Training Size: 26%, Epoch 40/50, Training Loss: 0.4284248451391856, Validation Loss: 0.44255608320236206
# Training Size: 26%, Epoch 50/50, Training Loss: 0.38235001762708026, Validation Loss: 0.403285663574934
# Accuracy: 0.76953125
#  F1-Score: 0.6101343101343102
# Training Size: 27%
# Training Size: 27%, Epoch 10/50, Training Loss: 0.6357030669848124, Validation Loss: 0.6295175403356552
# Training Size: 27%, Epoch 20/50, Training Loss: 0.6267902751763662, Validation Loss: 0.6222550235688686
# Training Size: 27%, Epoch 30/50, Training Loss: 0.5529263416926066, Validation Loss: 0.5399188883602619
# Training Size: 27%, Epoch 40/50, Training Loss: 0.40247363845507306, Validation Loss: 0.42477298341691494
# Training Size: 27%, Epoch 50/50, Training Loss: 0.342052365342776, Validation Loss: 0.3990688342601061
# Accuracy: 0.77734375
#  F1-Score: 0.622267573696145
# Training Size: 28%
# Training Size: 28%, Epoch 10/50, Training Loss: 0.6374625960985819, Validation Loss: 0.633011732250452
# Training Size: 28%, Epoch 20/50, Training Loss: 0.6177781522274017, Validation Loss: 0.6112087704241276
# Training Size: 28%, Epoch 30/50, Training Loss: 0.45130736629168194, Validation Loss: 0.4524985123425722
# Training Size: 28%, Epoch 40/50, Training Loss: 0.375968798995018, Validation Loss: 0.42658257484436035
# Training Size: 28%, Epoch 50/50, Training Loss: 0.3370867470900218, Validation Loss: 0.40206754952669144
# Accuracy: 0.79296875
#  F1-Score: 0.6764219576719577
# Training Size: 29%
# Training Size: 29%, Epoch 10/50, Training Loss: 0.6334245545523507, Validation Loss: 0.6276448965072632
# Training Size: 29%, Epoch 20/50, Training Loss: 0.6094003745487758, Validation Loss: 0.6030533472696941
# Training Size: 29%, Epoch 30/50, Training Loss: 0.43695750406810213, Validation Loss: 0.4563668131828308
# Training Size: 29%, Epoch 40/50, Training Loss: 0.3619426999773298, Validation Loss: 0.40770333210627235
# Training Size: 29%, Epoch 50/50, Training Loss: 0.3392451448099954, Validation Loss: 0.3863856712977091
# Accuracy: 0.78125
#  F1-Score: 0.6330260243632336
# Training Size: 30%
# Training Size: 30%, Epoch 10/50, Training Loss: 0.6403838651520866, Validation Loss: 0.637747609615326
# Training Size: 30%, Epoch 20/50, Training Loss: 0.5837867345128741, Validation Loss: 0.5686039447784423
# Training Size: 30%, Epoch 30/50, Training Loss: 0.41598405156816753, Validation Loss: 0.42883128523826597
# Training Size: 30%, Epoch 40/50, Training Loss: 0.3647757853780474, Validation Loss: 0.40267854928970337
# Training Size: 30%, Epoch 50/50, Training Loss: 0.3185261232512338, Validation Loss: 0.37059572140375774
# Accuracy: 0.8125
#  F1-Score: 0.7190557955762342
# Training Size: 31%
# Training Size: 31%, Epoch 10/50, Training Loss: 0.6302609103066581, Validation Loss: 0.626932688554128
# Training Size: 31%, Epoch 20/50, Training Loss: 0.6176025867462158, Validation Loss: 0.6106805125872294
# Training Size: 31%, Epoch 30/50, Training Loss: 0.4259511189801352, Validation Loss: 0.4362553079922994
# Training Size: 31%, Epoch 40/50, Training Loss: 0.3737483961241586, Validation Loss: 0.39354285995165506
# Training Size: 31%, Epoch 50/50, Training Loss: 0.3388067526476724, Validation Loss: 0.3886343061923981
# Accuracy: 0.80078125
#  F1-Score: 0.7012324161119879
# Training Size: 31%
# Training Size: 31%, Epoch 10/50, Training Loss: 0.6322627067565918, Validation Loss: 0.6281670610109965
# Training Size: 31%, Epoch 20/50, Training Loss: 0.6009532298360553, Validation Loss: 0.5860236644744873
# Training Size: 31%, Epoch 30/50, Training Loss: 0.41565006971359253, Validation Loss: 0.4292726953824361
# Training Size: 31%, Epoch 40/50, Training Loss: 0.35796420914786203, Validation Loss: 0.38901469111442566
# Training Size: 31%, Epoch 50/50, Training Loss: 0.3208113270146506, Validation Loss: 0.3753905912240346
# Accuracy: 0.81640625
#  F1-Score: 0.717743273675477
# Training Size: 32%
# Training Size: 32%, Epoch 10/50, Training Loss: 0.6317981140954154, Validation Loss: 0.6265842159589131
# Training Size: 32%, Epoch 20/50, Training Loss: 0.629020767552512, Validation Loss: 0.6228707313537598
# Training Size: 32%, Epoch 30/50, Training Loss: 0.5375814182417733, Validation Loss: 0.5222639441490173
# Training Size: 32%, Epoch 40/50, Training Loss: 0.38565086892672945, Validation Loss: 0.41163694659868877
# Training Size: 32%, Epoch 50/50, Training Loss: 0.34162495391709463, Validation Loss: 0.39728517532348634
# Accuracy: 0.78125
#  F1-Score: 0.6286647992530345
# Training Size: 34%
# Training Size: 34%, Epoch 10/50, Training Loss: 0.6334649473428726, Validation Loss: 0.629051570381437
# Training Size: 34%, Epoch 20/50, Training Loss: 0.6220290660858154, Validation Loss: 0.6206688497747693
# Training Size: 34%, Epoch 30/50, Training Loss: 0.47515420988202095, Validation Loss: 0.4686841198376247
# Training Size: 34%, Epoch 40/50, Training Loss: 0.3834046870470047, Validation Loss: 0.42139968063150135
# Training Size: 34%, Epoch 50/50, Training Loss: 0.37098196148872375, Validation Loss: 0.3933248498610088
# Accuracy: 0.796875
#  F1-Score: 0.6794047083520767
# Training Size: 35%
# Training Size: 35%, Epoch 10/50, Training Loss: 0.6278367787599564, Validation Loss: 0.6267918305737632
# Training Size: 35%, Epoch 20/50, Training Loss: 0.5956954061985016, Validation Loss: 0.5813628051962171
# Training Size: 35%, Epoch 30/50, Training Loss: 0.4030020423233509, Validation Loss: 0.4212301479918616
# Training Size: 35%, Epoch 40/50, Training Loss: 0.36737700551748276, Validation Loss: 0.41171833659921375
# Training Size: 35%, Epoch 50/50, Training Loss: 0.3145812675356865, Validation Loss: 0.3911705080951963
# Accuracy: 0.8359375
#  F1-Score: 0.797187112549938
# Training Size: 36%
# Training Size: 36%, Epoch 10/50, Training Loss: 0.6308089643716812, Validation Loss: 0.6271079395498548
# Training Size: 36%, Epoch 20/50, Training Loss: 0.615209087729454, Validation Loss: 0.602740113224302
# Training Size: 36%, Epoch 30/50, Training Loss: 0.4015691392123699, Validation Loss: 0.40798363941056387
# Training Size: 36%, Epoch 40/50, Training Loss: 0.34817520156502724, Validation Loss: 0.37192640560013907
# Training Size: 36%, Epoch 50/50, Training Loss: 0.31434550136327744, Validation Loss: 0.3613227754831314
# Accuracy: 0.83203125
#  F1-Score: 0.7849951783992286
# Training Size: 37%
# Training Size: 37%, Epoch 10/50, Training Loss: 0.6320250704884529, Validation Loss: 0.6283971667289734
# Training Size: 37%, Epoch 20/50, Training Loss: 0.6163188442587852, Validation Loss: 0.607101708650589
# Training Size: 37%, Epoch 30/50, Training Loss: 0.417758584022522, Validation Loss: 0.4263257682323456
# Training Size: 37%, Epoch 40/50, Training Loss: 0.36246419325470924, Validation Loss: 0.38826742342540194
# Training Size: 37%, Epoch 50/50, Training Loss: 0.3197191394865513, Validation Loss: 0.3712447477238519
# Accuracy: 0.859375
#  F1-Score: 0.8324346405228759
# Training Size: 38%
# Training Size: 38%, Epoch 10/50, Training Loss: 0.6557276182704501, Validation Loss: 0.6270090128694262
# Training Size: 38%, Epoch 20/50, Training Loss: 0.625114275349511, Validation Loss: 0.6301776596478054
# Training Size: 38%, Epoch 30/50, Training Loss: 0.5940613084369235, Validation Loss: 0.5798623519284385
# Training Size: 38%, Epoch 40/50, Training Loss: 0.42114289932780796, Validation Loss: 0.4382306401218687
# Training Size: 38%, Epoch 50/50, Training Loss: 0.4136594831943512, Validation Loss: 0.41044793810163227
# Accuracy: 0.7890625
#  F1-Score: 0.6561220642102995
# Training Size: 39%
# Training Size: 39%, Epoch 10/50, Training Loss: 0.6287959019343058, Validation Loss: 0.6239721637505752
# Training Size: 39%, Epoch 20/50, Training Loss: 0.5237279170089297, Validation Loss: 0.5015130363977872
# Training Size: 39%, Epoch 30/50, Training Loss: 0.37885478138923645, Validation Loss: 0.3941496450167436
# Training Size: 39%, Epoch 40/50, Training Loss: 0.3234920667277442, Validation Loss: 0.3817952573299408
# Training Size: 39%, Epoch 50/50, Training Loss: 0.2935728430747986, Validation Loss: 0.35504560057933515
# Accuracy: 0.83984375
#  F1-Score: 0.8069684283969998
# Training Size: 40%
# Training Size: 40%, Epoch 10/50, Training Loss: 0.6293922199143304, Validation Loss: 0.6245559041316693
# Training Size: 40%, Epoch 20/50, Training Loss: 0.4891538057062361, Validation Loss: 0.4769971026824071
# Training Size: 40%, Epoch 30/50, Training Loss: 0.37454135219256085, Validation Loss: 0.4013880720505348
# Training Size: 40%, Epoch 40/50, Training Loss: 0.32231056690216064, Validation Loss: 0.3758747165019696
# Training Size: 40%, Epoch 50/50, Training Loss: 0.28275217447015977, Validation Loss: 0.376843946484419
# Accuracy: 0.83203125
#  F1-Score: 0.7810457516339869
# Training Size: 41%
# Training Size: 41%, Epoch 10/50, Training Loss: 0.6299810939364963, Validation Loss: 0.624165090230795
# Training Size: 41%, Epoch 20/50, Training Loss: 0.4799343744913737, Validation Loss: 0.4635433027377495
# Training Size: 41%, Epoch 30/50, Training Loss: 0.37724343604511684, Validation Loss: 0.4208064560706799
# Training Size: 41%, Epoch 40/50, Training Loss: 0.3250041703383128, Validation Loss: 0.37316413109119123
# Training Size: 41%, Epoch 50/50, Training Loss: 0.29052675432629055, Validation Loss: 0.39475509295096767
# Accuracy: 0.8359375
#  F1-Score: 0.801550727818009
# Training Size: 42%
# Training Size: 42%, Epoch 10/50, Training Loss: 0.6257820924123129, Validation Loss: 0.6189153882173392
# Training Size: 42%, Epoch 20/50, Training Loss: 0.43444910314348006, Validation Loss: 0.44456819158334
# Training Size: 42%, Epoch 30/50, Training Loss: 0.34714918335278827, Validation Loss: 0.39394866503202
# Training Size: 42%, Epoch 40/50, Training Loss: 0.3056354158454471, Validation Loss: 0.37210198778372544
# Training Size: 42%, Epoch 50/50, Training Loss: 0.2717585265636444, Validation Loss: 0.3843907874364119
# Accuracy: 0.83984375
#  F1-Score: 0.8445616883116883
# Training Size: 43%
# Training Size: 43%, Epoch 10/50, Training Loss: 0.6287523984909058, Validation Loss: 0.6225452514795157
# Training Size: 43%, Epoch 20/50, Training Loss: 0.5815507471561432, Validation Loss: 0.5629665805743291
# Training Size: 43%, Epoch 30/50, Training Loss: 0.3832139879465103, Validation Loss: 0.41796179230396563
# Training Size: 43%, Epoch 40/50, Training Loss: 0.3198282182216644, Validation Loss: 0.40035505707447344
# Training Size: 43%, Epoch 50/50, Training Loss: 0.28569105714559556, Validation Loss: 0.4043306547861833
# Accuracy: 0.79296875
#  F1-Score: 0.6533898825988076
# Training Size: 43%
# Training Size: 43%, Epoch 10/50, Training Loss: 0.6291873157024384, Validation Loss: 0.6244132965803146
# Training Size: 43%, Epoch 20/50, Training Loss: 0.45407041907310486, Validation Loss: 0.46157701313495636
# Training Size: 43%, Epoch 30/50, Training Loss: 0.3444159537553787, Validation Loss: 0.3899495576818784
# Training Size: 43%, Epoch 40/50, Training Loss: 0.31754857301712036, Validation Loss: 0.3759339973330498
# Training Size: 43%, Epoch 50/50, Training Loss: 0.2564853712916374, Validation Loss: 0.35939135402441025
# Accuracy: 0.8515625
#  F1-Score: 0.8013130767229127
# Training Size: 44%
# Training Size: 44%, Epoch 10/50, Training Loss: 0.6274847149848938, Validation Loss: 0.6243622899055481
# Training Size: 44%, Epoch 20/50, Training Loss: 0.4272970288991928, Validation Loss: 0.4427169958750407
# Training Size: 44%, Epoch 30/50, Training Loss: 0.3306033432483673, Validation Loss: 0.3876392717162768
# Training Size: 44%, Epoch 40/50, Training Loss: 0.2842484027147293, Validation Loss: 0.37853104372819263
# Training Size: 44%, Epoch 50/50, Training Loss: 0.24207616299390794, Validation Loss: 0.3845736545821031
# Accuracy: 0.8203125
#  F1-Score: 0.7285883681535855
# Training Size: 46%
# Training Size: 46%, Epoch 10/50, Training Loss: 0.619866418838501, Validation Loss: 0.6140134632587433
# Training Size: 46%, Epoch 20/50, Training Loss: 0.40889781415462495, Validation Loss: 0.44205231219530106
# Training Size: 46%, Epoch 30/50, Training Loss: 0.3212899327278137, Validation Loss: 0.3807613675793012
# Training Size: 46%, Epoch 40/50, Training Loss: 0.29206336438655855, Validation Loss: 0.38842534522215527
# Training Size: 46%, Epoch 50/50, Training Loss: 0.24436039626598358, Validation Loss: 0.3811553344130516
# Accuracy: 0.83203125
#  F1-Score: 0.7379365079365079
# Training Size: 47%
# Training Size: 47%, Epoch 10/50, Training Loss: 0.6249812841415405, Validation Loss: 0.6233720978101095
# Training Size: 47%, Epoch 20/50, Training Loss: 0.4019870638847351, Validation Loss: 0.4192909523844719
# Training Size: 47%, Epoch 30/50, Training Loss: 0.3320954591035843, Validation Loss: 0.37907365212837857
# Training Size: 47%, Epoch 40/50, Training Loss: 0.27715244293212893, Validation Loss: 0.3585270208617051
# Training Size: 47%, Epoch 50/50, Training Loss: 0.23513771295547486, Validation Loss: 0.3689642511308193
# Accuracy: 0.8359375
#  F1-Score: 0.73996129656507
# Training Size: 48%
# Training Size: 48%, Epoch 10/50, Training Loss: 0.6207242499698292, Validation Loss: 0.6138268871740862
# Training Size: 48%, Epoch 20/50, Training Loss: 0.38888277248902753, Validation Loss: 0.42304729331623425
# Training Size: 48%, Epoch 30/50, Training Loss: 0.34362599524584686, Validation Loss: 0.3948813568462025
# Training Size: 48%, Epoch 40/50, Training Loss: 0.2788952738046646, Validation Loss: 0.3767289410937916
# Training Size: 48%, Epoch 50/50, Training Loss: 0.23912388357249173, Validation Loss: 0.3782203874804757
# Accuracy: 0.83203125
#  F1-Score: 0.7581997863247864
# Training Size: 49%
# Training Size: 49%, Epoch 10/50, Training Loss: 0.6261513775045221, Validation Loss: 0.6163980039683256
# Training Size: 49%, Epoch 20/50, Training Loss: 0.41510920362039044, Validation Loss: 0.4365188479423523
# Training Size: 49%, Epoch 30/50, Training Loss: 0.32970220663330774, Validation Loss: 0.3879196156154979
# Training Size: 49%, Epoch 40/50, Training Loss: 0.2747997018423947, Validation Loss: 0.3532659980383786
# Training Size: 49%, Epoch 50/50, Training Loss: 0.22541252320463007, Validation Loss: 0.35565131631764496
# Accuracy: 0.85546875
#  F1-Score: 0.8366208174812214
# Training Size: 50%
# Training Size: 50%, Epoch 10/50, Training Loss: 0.6104347163980658, Validation Loss: 0.5993322242390026
# Training Size: 50%, Epoch 20/50, Training Loss: 0.37245879660953174, Validation Loss: 0.42486225204034284
# Training Size: 50%, Epoch 30/50, Training Loss: 0.3171876072883606, Validation Loss: 0.39657180688597937
# Training Size: 50%, Epoch 40/50, Training Loss: 0.25328174097971484, Validation Loss: 0.37091017311269586
# Training Size: 50%, Epoch 50/50, Training Loss: 0.22223820875991473, Validation Loss: 0.3798193254254081
# Accuracy: 0.8515625
#  F1-Score: 0.7997171945701357
# Training Size: 51%
# Training Size: 51%, Epoch 10/50, Training Loss: 0.6145562529563904, Validation Loss: 0.6037651083686135
# Training Size: 51%, Epoch 20/50, Training Loss: 0.38263834606517444, Validation Loss: 0.3786313831806183
# Training Size: 51%, Epoch 30/50, Training Loss: 0.30449744110757654, Validation Loss: 0.3273359537124634
# Training Size: 51%, Epoch 40/50, Training Loss: 0.2580440491437912, Validation Loss: 0.3035229579968886
# Training Size: 51%, Epoch 50/50, Training Loss: 0.20941150052980942, Validation Loss: 0.28319114446640015
# Accuracy: 0.83984375
#  F1-Score: 0.767258927031223
# Training Size: 52%
# Training Size: 52%, Epoch 10/50, Training Loss: 0.6188085404309359, Validation Loss: 0.6070257858796553
# Training Size: 52%, Epoch 20/50, Training Loss: 0.38910993933677673, Validation Loss: 0.3876615979454734
# Training Size: 52%, Epoch 30/50, Training Loss: 0.3018293922597712, Validation Loss: 0.3229669007388028
# Training Size: 52%, Epoch 40/50, Training Loss: 0.26279870623892004, Validation Loss: 0.2997012138366699
# Training Size: 52%, Epoch 50/50, Training Loss: 0.22330467809330334, Validation Loss: 0.28797420588406647
# Accuracy: 0.84765625
#  F1-Score: 0.7816734340927889
# Training Size: 53%
# Training Size: 53%, Epoch 10/50, Training Loss: 0.6054687947034836, Validation Loss: 0.5950312197208405
# Training Size: 53%, Epoch 20/50, Training Loss: 0.3782537132501602, Validation Loss: 0.3941699147224426
# Training Size: 53%, Epoch 30/50, Training Loss: 0.3020428617795308, Validation Loss: 0.33157157599925996
# Training Size: 53%, Epoch 40/50, Training Loss: 0.2550509423017502, Validation Loss: 0.30869258046150205
# Training Size: 53%, Epoch 50/50, Training Loss: 0.20956248169143996, Validation Loss: 0.2925735890865326
# Accuracy: 0.8671875
#  F1-Score: 0.8430861928104576
# Training Size: 54%
# Training Size: 54%, Epoch 10/50, Training Loss: 0.6168325891097387, Validation Loss: 0.6064679086208343
# Training Size: 54%, Epoch 20/50, Training Loss: 0.3825364038348198, Validation Loss: 0.37888849675655367
# Training Size: 54%, Epoch 30/50, Training Loss: 0.2996178828179836, Validation Loss: 0.33605660796165465
# Training Size: 54%, Epoch 40/50, Training Loss: 0.2461460866034031, Validation Loss: 0.2878012865781784
# Training Size: 54%, Epoch 50/50, Training Loss: 0.21217075983683267, Validation Loss: 0.2917111873626709
# Accuracy: 0.8515625
#  F1-Score: 0.7853320818055647
# Training Size: 55%
# Training Size: 55%, Epoch 10/50, Training Loss: 0.591495136419932, Validation Loss: 0.5736426055431366
# Training Size: 55%, Epoch 20/50, Training Loss: 0.3692868848641713, Validation Loss: 0.3763084203004837
# Training Size: 55%, Epoch 30/50, Training Loss: 0.3029915976027648, Validation Loss: 0.32828797996044157
# Training Size: 55%, Epoch 40/50, Training Loss: 0.24490393698215485, Validation Loss: 0.2990665853023529
# Training Size: 55%, Epoch 50/50, Training Loss: 0.19954262798031172, Validation Loss: 0.2781978100538254
# Accuracy: 0.859375
#  F1-Score: 0.800979020979021
# Training Size: 56%
# Training Size: 56%, Epoch 10/50, Training Loss: 0.5150407130519549, Validation Loss: 0.4949194997549057
# Training Size: 56%, Epoch 20/50, Training Loss: 0.3471829295158386, Validation Loss: 0.3558974087238312
# Training Size: 56%, Epoch 30/50, Training Loss: 0.2787185112635295, Validation Loss: 0.31265625953674314
# Training Size: 56%, Epoch 40/50, Training Loss: 0.22837426389257112, Validation Loss: 0.30927866995334624
# Training Size: 56%, Epoch 50/50, Training Loss: 0.1948723333577315, Validation Loss: 0.28533204048871996
# Accuracy: 0.8828125
#  F1-Score: 0.8618944547515976
# Training Size: 57%
# Training Size: 57%, Epoch 10/50, Training Loss: 0.6126271486282349, Validation Loss: 0.6070420682430268
# Training Size: 57%, Epoch 20/50, Training Loss: 0.39411024634654707, Validation Loss: 0.40239301025867463
# Training Size: 57%, Epoch 30/50, Training Loss: 0.3388090385840489, Validation Loss: 0.3633384257555008
# Training Size: 57%, Epoch 40/50, Training Loss: 0.2886728529746716, Validation Loss: 0.33299122750759125
# Training Size: 57%, Epoch 50/50, Training Loss: 0.2904485372396616, Validation Loss: 0.32199386656284334
# Accuracy: 0.85546875
#  F1-Score: 0.8365186257151263
# Training Size: 58%
# Training Size: 58%, Epoch 10/50, Training Loss: 0.48654888226435733, Validation Loss: 0.4715108705891503
# Training Size: 58%, Epoch 20/50, Training Loss: 0.35062145728331345, Validation Loss: 0.37685397929615444
# Training Size: 58%, Epoch 30/50, Training Loss: 0.27667077573446125, Validation Loss: 0.30596739716000027
# Training Size: 58%, Epoch 40/50, Training Loss: 0.2246459940305123, Validation Loss: 0.2797534399562412
# Training Size: 58%, Epoch 50/50, Training Loss: 0.19073932331341964, Validation Loss: 0.2734609693288803
# Accuracy: 0.8515625
#  F1-Score: 0.8288203957382039
# Training Size: 59%
# Training Size: 59%, Epoch 10/50, Training Loss: 0.5645031929016113, Validation Loss: 0.5484093957477145
# Training Size: 59%, Epoch 20/50, Training Loss: 0.33868077168097865, Validation Loss: 0.35931552118725246
# Training Size: 59%, Epoch 30/50, Training Loss: 0.2748668354291182, Validation Loss: 0.3263136115339067
# Training Size: 59%, Epoch 40/50, Training Loss: 0.22726070078519675, Validation Loss: 0.2848221825228797
# Training Size: 59%, Epoch 50/50, Training Loss: 0.197373445217426, Validation Loss: 0.2812716629770067
# Accuracy: 0.8671875
#  F1-Score: 0.8429527725068522
# Training Size: 60%
# Training Size: 60%, Epoch 10/50, Training Loss: 0.5226153616721814, Validation Loss: 0.49935216042730546
# Training Size: 60%, Epoch 20/50, Training Loss: 0.34095586033967823, Validation Loss: 0.35532142056359184
# Training Size: 60%, Epoch 30/50, Training Loss: 0.2648281432115115, Validation Loss: 0.300869087378184
# Training Size: 60%, Epoch 40/50, Training Loss: 0.207194080719581, Validation Loss: 0.2647366341617372
# Training Size: 60%, Epoch 50/50, Training Loss: 0.18157449250037855, Validation Loss: 0.2693308922979567
# Accuracy: 0.8671875
#  F1-Score: 0.8247603121516165
# Training Size: 61%
# Training Size: 61%, Epoch 10/50, Training Loss: 0.5153330518649175, Validation Loss: 0.48905714352925617
# Training Size: 61%, Epoch 20/50, Training Loss: 0.3302035400500664, Validation Loss: 0.34883198142051697
# Training Size: 61%, Epoch 30/50, Training Loss: 0.26793015461701614, Validation Loss: 0.30861621763971114
# Training Size: 61%, Epoch 40/50, Training Loss: 0.2133981493803171, Validation Loss: 0.27417197657956016
# Training Size: 61%, Epoch 50/50, Training Loss: 0.18654846571958983, Validation Loss: 0.27508317099677193
# Accuracy: 0.84375
#  F1-Score: 0.7951515151515152
# Training Size: 62%
# Training Size: 62%, Epoch 10/50, Training Loss: 0.46062011803899494, Validation Loss: 0.44325247075822616
# Training Size: 62%, Epoch 20/50, Training Loss: 0.31386310926505495, Validation Loss: 0.32863043083084953
# Training Size: 62%, Epoch 30/50, Training Loss: 0.26338846342904226, Validation Loss: 0.30803858240445453
# Training Size: 62%, Epoch 40/50, Training Loss: 0.22249335582767213, Validation Loss: 0.27763230933083427
# Training Size: 62%, Epoch 50/50, Training Loss: 0.19585558346339635, Validation Loss: 0.2805735435750749
# Accuracy: 0.83984375
#  F1-Score: 0.7797086130049504
# Training Size: 63%
# Training Size: 63%, Epoch 10/50, Training Loss: 0.4742292101894106, Validation Loss: 0.4570241905748844
# Training Size: 63%, Epoch 20/50, Training Loss: 0.3192834385803768, Validation Loss: 0.35559428110718727
# Training Size: 63%, Epoch 30/50, Training Loss: 0.253999079976763, Validation Loss: 0.30860621482133865
# Training Size: 63%, Epoch 40/50, Training Loss: 0.21453706600836345, Validation Loss: 0.2682821452617645
# Training Size: 63%, Epoch 50/50, Training Loss: 0.1816265412739345, Validation Loss: 0.30671222135424614
# Accuracy: 0.8671875
#  F1-Score: 0.7924369747899159
# Training Size: 64%
# Training Size: 64%, Epoch 10/50, Training Loss: 0.4490263802664621, Validation Loss: 0.4291975870728493
# Training Size: 64%, Epoch 20/50, Training Loss: 0.32624399236270357, Validation Loss: 0.34784336388111115
# Training Size: 64%, Epoch 30/50, Training Loss: 0.24457890540361404, Validation Loss: 0.29785340279340744
# Training Size: 64%, Epoch 40/50, Training Loss: 0.20621937194040843, Validation Loss: 0.28094095550477505
# Training Size: 64%, Epoch 50/50, Training Loss: 0.18120829122407095, Validation Loss: 0.2621627673506737
# Accuracy: 0.87109375
#  F1-Score: 0.8486240510697032
# Training Size: 65%
# Training Size: 65%, Epoch 10/50, Training Loss: 0.47121657856873106, Validation Loss: 0.4504299908876419
# Training Size: 65%, Epoch 20/50, Training Loss: 0.3089196277516229, Validation Loss: 0.33417240530252457
# Training Size: 65%, Epoch 30/50, Training Loss: 0.24435379143272126, Validation Loss: 0.28408512473106384
# Training Size: 65%, Epoch 40/50, Training Loss: 0.20460160502365657, Validation Loss: 0.2844514213502407
# Training Size: 65%, Epoch 50/50, Training Loss: 0.1695902565760272, Validation Loss: 0.2735886890441179
# Accuracy: 0.8671875
#  F1-Score: 0.8100082270670506
# Training Size: 65%
# Training Size: 65%, Epoch 10/50, Training Loss: 0.4850482557501112, Validation Loss: 0.4645970091223717
# Training Size: 65%, Epoch 20/50, Training Loss: 0.3188393073422568, Validation Loss: 0.3504539132118225
# Training Size: 65%, Epoch 30/50, Training Loss: 0.25915033902440754, Validation Loss: 0.30892015248537064
# Training Size: 65%, Epoch 40/50, Training Loss: 0.2106025591492653, Validation Loss: 0.30424854159355164
# Training Size: 65%, Epoch 50/50, Training Loss: 0.1821243315935135, Validation Loss: 0.31868401914834976
# Accuracy: 0.859375
#  F1-Score: 0.7806254684592023
# Training Size: 67%
# Training Size: 67%, Epoch 10/50, Training Loss: 0.40237663785616556, Validation Loss: 0.40649430240903583
# Training Size: 67%, Epoch 20/50, Training Loss: 0.30877519051233926, Validation Loss: 0.3393907589571817
# Training Size: 67%, Epoch 30/50, Training Loss: 0.2388215055068334, Validation Loss: 0.3228750399180821
# Training Size: 67%, Epoch 40/50, Training Loss: 0.2092442532380422, Validation Loss: 0.27698705877576557
# Training Size: 67%, Epoch 50/50, Training Loss: 0.17796442310015362, Validation Loss: 0.29695819318294525
# Accuracy: 0.85546875
#  F1-Score: 0.8051989389920423
# Training Size: 68%
# Training Size: 68%, Epoch 10/50, Training Loss: 0.43687918583552043, Validation Loss: 0.41732510924339294
# Training Size: 68%, Epoch 20/50, Training Loss: 0.31096123258272806, Validation Loss: 0.3333540175642286
# Training Size: 68%, Epoch 30/50, Training Loss: 0.2436857481797536, Validation Loss: 0.2786196172237396
# Training Size: 68%, Epoch 40/50, Training Loss: 0.20143788655598957, Validation Loss: 0.3183899564402444
# Training Size: 68%, Epoch 50/50, Training Loss: 0.1815193235874176, Validation Loss: 0.2518216350248882
# Accuracy: 0.87109375
#  F1-Score: 0.8521205566371044
# Training Size: 69%
# Training Size: 69%, Epoch 10/50, Training Loss: 0.4163476904233297, Validation Loss: 0.41546579769679476
# Training Size: 69%, Epoch 20/50, Training Loss: 0.2846621046463648, Validation Loss: 0.3117732788835253
# Training Size: 69%, Epoch 30/50, Training Loss: 0.2306097278992335, Validation Loss: 0.2729260282857077
# Training Size: 69%, Epoch 40/50, Training Loss: 0.1911892424027125, Validation Loss: 0.26839122601917814
# Training Size: 69%, Epoch 50/50, Training Loss: 0.15794685383637747, Validation Loss: 0.25429263498101917
# Accuracy: 0.8671875
#  F1-Score: 0.8213858424725823
# Training Size: 70%
# Training Size: 70%, Epoch 10/50, Training Loss: 0.411422598361969, Validation Loss: 0.4005409564290728
# Training Size: 70%, Epoch 20/50, Training Loss: 0.2828723073005676, Validation Loss: 0.3042953482695988
# Training Size: 70%, Epoch 30/50, Training Loss: 0.22582014203071593, Validation Loss: 0.27855212347848074
# Training Size: 70%, Epoch 40/50, Training Loss: 0.18138293425242105, Validation Loss: 0.26797992416790556
# Training Size: 70%, Epoch 50/50, Training Loss: 0.1603808432817459, Validation Loss: 0.25519284180232454
# Accuracy: 0.87890625
#  F1-Score: 0.8346938775510204
# Training Size: 71%
# Training Size: 71%, Epoch 10/50, Training Loss: 0.4015845715999603, Validation Loss: 0.39404099753924776
# Training Size: 71%, Epoch 20/50, Training Loss: 0.2988025446732839, Validation Loss: 0.3270892245428903
# Training Size: 71%, Epoch 30/50, Training Loss: 0.23553914030392964, Validation Loss: 0.284893057176045
# Training Size: 71%, Epoch 40/50, Training Loss: 0.1925162394841512, Validation Loss: 0.27693227359226774
# Training Size: 71%, Epoch 50/50, Training Loss: 0.1563440427184105, Validation Loss: 0.2637398477111544
# Accuracy: 0.85546875
#  F1-Score: 0.8107843137254902
# Training Size: 72%
# Training Size: 72%, Epoch 10/50, Training Loss: 0.39600135385990143, Validation Loss: 0.389329398671786
# Training Size: 72%, Epoch 20/50, Training Loss: 0.2862471779808402, Validation Loss: 0.3061077545086543
# Training Size: 72%, Epoch 30/50, Training Loss: 0.21497120335698128, Validation Loss: 0.2681436662872632
# Training Size: 72%, Epoch 40/50, Training Loss: 0.17497946694493294, Validation Loss: 0.26527784764766693
# Training Size: 72%, Epoch 50/50, Training Loss: 0.136159788351506, Validation Loss: 0.27166825036207837
# Accuracy: 0.87890625
#  F1-Score: 0.8316482843137255
# Training Size: 73%
# Training Size: 73%, Epoch 10/50, Training Loss: 0.4136234652251005, Validation Loss: 0.4118810296058655
# Training Size: 73%, Epoch 20/50, Training Loss: 0.28819247987121344, Validation Loss: 0.32026231785615283
# Training Size: 73%, Epoch 30/50, Training Loss: 0.22918756399303675, Validation Loss: 0.279767503341039
# Training Size: 73%, Epoch 40/50, Training Loss: 0.19226684421300888, Validation Loss: 0.26961324612299603
# Training Size: 73%, Epoch 50/50, Training Loss: 0.15734084276482463, Validation Loss: 0.261193407078584
# Accuracy: 0.87109375
#  F1-Score: 0.8439261669580113
# Training Size: 74%
# Training Size: 74%, Epoch 10/50, Training Loss: 0.39505139365792274, Validation Loss: 0.38724549611409503
# Training Size: 74%, Epoch 20/50, Training Loss: 0.2850400758907199, Validation Loss: 0.3084596296151479
# Training Size: 74%, Epoch 30/50, Training Loss: 0.22235308587551117, Validation Loss: 0.25740743428468704
# Training Size: 74%, Epoch 40/50, Training Loss: 0.18552175164222717, Validation Loss: 0.25278552373250324
# Training Size: 74%, Epoch 50/50, Training Loss: 0.14525963878259063, Validation Loss: 0.27150704463322956
# Accuracy: 0.8671875
#  F1-Score: 0.8228125000000001
# Training Size: 75%
# Training Size: 75%, Epoch 10/50, Training Loss: 0.3992327470332384, Validation Loss: 0.3998873035113017
# Training Size: 75%, Epoch 20/50, Training Loss: 0.2830676771700382, Validation Loss: 0.3237848977247874
# Training Size: 75%, Epoch 30/50, Training Loss: 0.21399432234466076, Validation Loss: 0.2641234149535497
# Training Size: 75%, Epoch 40/50, Training Loss: 0.1905396431684494, Validation Loss: 0.2654155691464742
# Training Size: 75%, Epoch 50/50, Training Loss: 0.14481662726029754, Validation Loss: 0.2800748646259308
# Accuracy: 0.87109375
#  F1-Score: 0.84828974556806
# Training Size: 76%
# Training Size: 76%, Epoch 10/50, Training Loss: 0.401112626580631, Validation Loss: 0.39621110260486603
# Training Size: 76%, Epoch 20/50, Training Loss: 0.31621285045848174, Validation Loss: 0.300075223048528
# Training Size: 76%, Epoch 30/50, Training Loss: 0.24834194867049947, Validation Loss: 0.2729807247718175
# Training Size: 76%, Epoch 40/50, Training Loss: 0.205555516130784, Validation Loss: 0.2444696327050527
# Training Size: 76%, Epoch 50/50, Training Loss: 0.17566913716933308, Validation Loss: 0.2444193164507548
# Accuracy: 0.8828125
#  F1-Score: 0.8617177592430006
# Training Size: 77%
# Training Size: 77%, Epoch 10/50, Training Loss: 0.3852714247563306, Validation Loss: 0.3751793146133423
# Training Size: 77%, Epoch 20/50, Training Loss: 0.2742648256175658, Validation Loss: 0.3075790822505951
# Training Size: 77%, Epoch 30/50, Training Loss: 0.2206646028686972, Validation Loss: 0.27323958873748777
# Training Size: 77%, Epoch 40/50, Training Loss: 0.17766889973598368, Validation Loss: 0.27605710327625277
# Training Size: 77%, Epoch 50/50, Training Loss: 0.1501215341336587, Validation Loss: 0.2631544053554535
# Accuracy: 0.875
#  F1-Score: 0.8482462335216573
# Training Size: 78%
# Training Size: 78%, Epoch 10/50, Training Loss: 0.3726888789850123, Validation Loss: 0.36260679364204407
# Training Size: 78%, Epoch 20/50, Training Loss: 0.25665437211008635, Validation Loss: 0.2921058475971222
# Training Size: 78%, Epoch 30/50, Training Loss: 0.20557384543559132, Validation Loss: 0.2664747327566147
# Training Size: 78%, Epoch 40/50, Training Loss: 0.1671026647090912, Validation Loss: 0.2596593856811523
# Training Size: 78%, Epoch 50/50, Training Loss: 0.13882234473438823, Validation Loss: 0.26444328129291533
# Accuracy: 0.8828125
#  F1-Score: 0.8583702298123551
# Training Size: 79%
# Training Size: 79%, Epoch 10/50, Training Loss: 0.37560830046148863, Validation Loss: 0.3885656535625458
# Training Size: 79%, Epoch 20/50, Training Loss: 0.27633649549063516, Validation Loss: 0.29974888563156127
# Training Size: 79%, Epoch 30/50, Training Loss: 0.23309661097386303, Validation Loss: 0.2898070514202118
# Training Size: 79%, Epoch 40/50, Training Loss: 0.17317137122154236, Validation Loss: 0.25951156914234164
# Training Size: 79%, Epoch 50/50, Training Loss: 0.13612531081718557, Validation Loss: 0.26455748081207275
# Accuracy: 0.875
#  F1-Score: 0.8518450390909051
# Training Size: 80%
# Training Size: 80%, Epoch 10/50, Training Loss: 0.3848266443785499, Validation Loss: 0.3711669147014618
# Training Size: 80%, Epoch 20/50, Training Loss: 0.2629322348272099, Validation Loss: 0.29115707874298097
# Training Size: 80%, Epoch 30/50, Training Loss: 0.20727709724622614, Validation Loss: 0.27056211829185484
# Training Size: 80%, Epoch 40/50, Training Loss: 0.17209776359445908, Validation Loss: 0.2529062956571579
# Training Size: 80%, Epoch 50/50, Training Loss: 0.14352103366571314, Validation Loss: 0.25490828454494474
# Accuracy: 0.859375
#  F1-Score: 0.8121001031991744
# Training Size: 81%
# Training Size: 81%, Epoch 10/50, Training Loss: 0.36387668550014496, Validation Loss: 0.3353093653917313
# Training Size: 81%, Epoch 20/50, Training Loss: 0.25839036371972823, Validation Loss: 0.23473680578172207
# Training Size: 81%, Epoch 30/50, Training Loss: 0.20064033650689655, Validation Loss: 0.21651387873571365
# Training Size: 81%, Epoch 40/50, Training Loss: 0.16201177115241686, Validation Loss: 0.21340709754731507
# Training Size: 81%, Epoch 50/50, Training Loss: 0.13428488125403723, Validation Loss: 0.21552101595734713
# Accuracy: 0.8828125
#  F1-Score: 0.8524315941065692
# Training Size: 82%
# Training Size: 82%, Epoch 10/50, Training Loss: 0.3769460833734936, Validation Loss: 0.3645988032221794
# Training Size: 82%, Epoch 20/50, Training Loss: 0.252931098971102, Validation Loss: 0.297242671251297
# Training Size: 82%, Epoch 30/50, Training Loss: 0.19999602850940493, Validation Loss: 0.2722234018146992
# Training Size: 82%, Epoch 40/50, Training Loss: 0.15347087052133349, Validation Loss: 0.3035059943795204
# Training Size: 82%, Epoch 50/50, Training Loss: 0.13662806443042225, Validation Loss: 0.33103542774915695
# Accuracy: 0.88671875
#  F1-Score: 0.8585153152791172
# Training Size: 83%
# Training Size: 83%, Epoch 10/50, Training Loss: 0.36694201330343884, Validation Loss: 0.34564468264579773
# Training Size: 83%, Epoch 20/50, Training Loss: 0.23471658676862717, Validation Loss: 0.2828086093068123
# Training Size: 83%, Epoch 30/50, Training Loss: 0.1869218556417359, Validation Loss: 0.2677151598036289
# Training Size: 83%, Epoch 40/50, Training Loss: 0.15106622502207756, Validation Loss: 0.25240155681967735
# Training Size: 83%, Epoch 50/50, Training Loss: 0.11936564039852884, Validation Loss: 0.2679581344127655
# Accuracy: 0.87109375
#  F1-Score: 0.8436104754640223
# Training Size: 84%
# Training Size: 84%, Epoch 10/50, Training Loss: 0.37514326969782513, Validation Loss: 0.36086300760507584
# Training Size: 84%, Epoch 20/50, Training Loss: 0.25073233246803284, Validation Loss: 0.27260204777121544
# Training Size: 84%, Epoch 30/50, Training Loss: 0.20596123735109964, Validation Loss: 0.2730998396873474
# Training Size: 84%, Epoch 40/50, Training Loss: 0.16802573121256298, Validation Loss: 0.26510652154684067
# Training Size: 84%, Epoch 50/50, Training Loss: 0.12001725782950719, Validation Loss: 0.28022102266550064
# Accuracy: 0.8671875
#  F1-Score: 0.8367055290584702
# Training Size: 85%
# Training Size: 85%, Epoch 10/50, Training Loss: 0.3605959332651562, Validation Loss: 0.32697843760252
# Training Size: 85%, Epoch 20/50, Training Loss: 0.2397935481535064, Validation Loss: 0.24831034988164902
# Training Size: 85%, Epoch 30/50, Training Loss: 0.1945220852891604, Validation Loss: 0.23339026048779488
# Training Size: 85%, Epoch 40/50, Training Loss: 0.14922508266237047, Validation Loss: 0.239344272762537
# Training Size: 85%, Epoch 50/50, Training Loss: 0.13392444948355356, Validation Loss: 0.23687727749347687
# Accuracy: 0.86328125
#  F1-Score: 0.8322357907432534
# Training Size: 86%
# Training Size: 86%, Epoch 10/50, Training Loss: 0.3549971988326625, Validation Loss: 0.34124938646952313
# Training Size: 86%, Epoch 20/50, Training Loss: 0.24428287070048482, Validation Loss: 0.319733202457428
# Training Size: 86%, Epoch 30/50, Training Loss: 0.1860802981414293, Validation Loss: 0.26901207367579144
# Training Size: 86%, Epoch 40/50, Training Loss: 0.14397784008791573, Validation Loss: 0.2708835005760193
# Training Size: 86%, Epoch 50/50, Training Loss: 0.1242197104974797, Validation Loss: 0.2584792772928874
# Accuracy: 0.87890625
#  F1-Score: 0.8510117320428406
# Training Size: 87%
# Training Size: 87%, Epoch 10/50, Training Loss: 0.3476930935131876, Validation Loss: 0.3491523762543996
# Training Size: 87%, Epoch 20/50, Training Loss: 0.23406411472119784, Validation Loss: 0.2734030981858571
# Training Size: 87%, Epoch 30/50, Training Loss: 0.1903545629037054, Validation Loss: 0.27419554193814594
# Training Size: 87%, Epoch 40/50, Training Loss: 0.14146591958246732, Validation Loss: 0.27930688858032227
# Training Size: 87%, Epoch 50/50, Training Loss: 0.10242659382914242, Validation Loss: 0.2739025106032689
# Accuracy: 0.88671875
#  F1-Score: 0.8318048829701372
# Training Size: 88%
# Training Size: 88%, Epoch 10/50, Training Loss: 0.3606087549736625, Validation Loss: 0.3431045413017273
# Training Size: 88%, Epoch 20/50, Training Loss: 0.24154812019122274, Validation Loss: 0.28492693106333417
# Training Size: 88%, Epoch 30/50, Training Loss: 0.18979735986182564, Validation Loss: 0.28924548625946045
# Training Size: 88%, Epoch 40/50, Training Loss: 0.15220524684378975, Validation Loss: 0.3111765682697296
# Training Size: 88%, Epoch 50/50, Training Loss: 0.11953651748205486, Validation Loss: 0.31239022811253864
# Accuracy: 0.875
#  F1-Score: 0.8453605584679539
# Training Size: 89%
# Training Size: 89%, Epoch 10/50, Training Loss: 0.34084193800625046, Validation Loss: 0.38333455721537274
# Training Size: 89%, Epoch 20/50, Training Loss: 0.2403791319382818, Validation Loss: 0.3030209044615428
# Training Size: 89%, Epoch 30/50, Training Loss: 0.17671141773462296, Validation Loss: 0.2986254592736562
# Training Size: 89%, Epoch 40/50, Training Loss: 0.13275640693150068, Validation Loss: 0.26889602343241376
# Training Size: 89%, Epoch 50/50, Training Loss: 0.09862404826440309, Validation Loss: 0.2737966924905777
# Accuracy: 0.89453125
#  F1-Score: 0.8919480519480519
# Training Size: 90%
# Training Size: 90%, Epoch 10/50, Training Loss: 0.35853051511864914, Validation Loss: 0.35571369528770447
# Training Size: 90%, Epoch 20/50, Training Loss: 0.2522008936656149, Validation Loss: 0.32877281308174133
# Training Size: 90%, Epoch 30/50, Training Loss: 0.2028037788052308, Validation Loss: 0.3428710202376048
# Training Size: 90%, Epoch 40/50, Training Loss: 0.15003865878832967, Validation Loss: 0.31567378838857013
# Training Size: 90%, Epoch 50/50, Training Loss: 0.11779495603159855, Validation Loss: 0.33711468676726025
# Accuracy: 0.87109375
#  F1-Score: 0.8254138321995464
# Training Size: 91%
# Training Size: 91%, Epoch 10/50, Training Loss: 0.3429383605718613, Validation Loss: 0.36375562846660614
# Training Size: 91%, Epoch 20/50, Training Loss: 0.24880255237221718, Validation Loss: 0.2753211557865143
# Training Size: 91%, Epoch 30/50, Training Loss: 0.18942029029130936, Validation Loss: 0.25864988565444946
# Training Size: 91%, Epoch 40/50, Training Loss: 0.152016144618392, Validation Loss: 0.2406785935163498
# Training Size: 91%, Epoch 50/50, Training Loss: 0.11827103197574615, Validation Loss: 0.2355898916721344
# Accuracy: 0.88671875
#  F1-Score: 0.8596193605174814
# Training Size: 92%
# Training Size: 92%, Epoch 10/50, Training Loss: 0.3367871522903442, Validation Loss: 0.3402198851108551
# Training Size: 92%, Epoch 20/50, Training Loss: 0.23069795742630958, Validation Loss: 0.25965122878551483
# Training Size: 92%, Epoch 30/50, Training Loss: 0.18015051484107972, Validation Loss: 0.22724758833646774
# Training Size: 92%, Epoch 40/50, Training Loss: 0.12988598346710206, Validation Loss: 0.26766935735940933
# Training Size: 92%, Epoch 50/50, Training Loss: 0.10336377993226051, Validation Loss: 0.2558247148990631
# Accuracy: 0.88671875
#  F1-Score: 0.8323031949098048
# Training Size: 93%
# Training Size: 93%, Epoch 10/50, Training Loss: 0.32167401611804963, Validation Loss: 0.30046936869621277
# Training Size: 93%, Epoch 20/50, Training Loss: 0.2323691502213478, Validation Loss: 0.26760825514793396
# Training Size: 93%, Epoch 30/50, Training Loss: 0.1722365390509367, Validation Loss: 0.2637484446167946
# Training Size: 93%, Epoch 40/50, Training Loss: 0.14171540252864362, Validation Loss: 0.25608014315366745
# Training Size: 93%, Epoch 50/50, Training Loss: 0.10916104540228844, Validation Loss: 0.26985199749469757
# Accuracy: 0.87890625
#  F1-Score: 0.8418855447480073
# Training Size: 94%
# Training Size: 94%, Epoch 10/50, Training Loss: 0.3111967869102955, Validation Loss: 0.2877894788980484
# Training Size: 94%, Epoch 20/50, Training Loss: 0.21870653852820396, Validation Loss: 0.30011042952537537
# Training Size: 94%, Epoch 30/50, Training Loss: 0.16162073388695716, Validation Loss: 0.2839871570467949
# Training Size: 94%, Epoch 40/50, Training Loss: 0.13003414124250412, Validation Loss: 0.2989063411951065
# Training Size: 94%, Epoch 50/50, Training Loss: 0.09511891603469849, Validation Loss: 0.31881949305534363
# Accuracy: 0.88671875
#  F1-Score: 0.8530272764843642
# Training Size: 95%
# Training Size: 95%, Epoch 10/50, Training Loss: 0.3464940736691157, Validation Loss: 0.4353943318128586
# Training Size: 95%, Epoch 20/50, Training Loss: 0.28067931674775626, Validation Loss: 0.4042319357395172
# Training Size: 95%, Epoch 30/50, Training Loss: 0.1939593092316673, Validation Loss: 0.38332659006118774
# Training Size: 95%, Epoch 40/50, Training Loss: 0.15399526130585445, Validation Loss: 0.3995981067419052
# Training Size: 95%, Epoch 50/50, Training Loss: 0.13125344259398325, Validation Loss: 0.3689640760421753
# Accuracy: 0.90234375
#  F1-Score: 0.8765236037917992

# %%
# Print the results for different training sizes
for result in results:
    print(f"Training Size: {result['Training Size']}%, "
          f"Multi-label Validation Accuracy: {result['Multi-label Validation Accuracy'] * 100:.2f}%, "
          f"F1 Score: {result['F1 Score']:.2f}")
# Out:
# Training Size: 5%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 6%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 6%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 7%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 8%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 9%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 10%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 12%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 13%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 14%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 15%, Multi-label Validation Accuracy: 63.28%, F1 Score: 0.00
# Training Size: 16%, Multi-label Validation Accuracy: 67.58%, F1 Score: 0.19
# Training Size: 17%, Multi-label Validation Accuracy: 64.06%, F1 Score: 0.05
# Training Size: 18%, Multi-label Validation Accuracy: 63.67%, F1 Score: 0.02
# Training Size: 18%, Multi-label Validation Accuracy: 72.66%, F1 Score: 0.34
# Training Size: 19%, Multi-label Validation Accuracy: 69.14%, F1 Score: 0.25
# Training Size: 20%, Multi-label Validation Accuracy: 76.17%, F1 Score: 0.57
# Training Size: 21%, Multi-label Validation Accuracy: 74.61%, F1 Score: 0.56
# Training Size: 23%, Multi-label Validation Accuracy: 74.61%, F1 Score: 0.57
# Training Size: 24%, Multi-label Validation Accuracy: 67.19%, F1 Score: 0.19
# Training Size: 25%, Multi-label Validation Accuracy: 78.91%, F1 Score: 0.65
# Training Size: 26%, Multi-label Validation Accuracy: 76.95%, F1 Score: 0.61
# Training Size: 27%, Multi-label Validation Accuracy: 77.73%, F1 Score: 0.62
# Training Size: 28%, Multi-label Validation Accuracy: 79.30%, F1 Score: 0.68
# Training Size: 29%, Multi-label Validation Accuracy: 78.12%, F1 Score: 0.63
# Training Size: 30%, Multi-label Validation Accuracy: 81.25%, F1 Score: 0.72
# Training Size: 31%, Multi-label Validation Accuracy: 80.08%, F1 Score: 0.70
# Training Size: 31%, Multi-label Validation Accuracy: 81.64%, F1 Score: 0.72
# Training Size: 32%, Multi-label Validation Accuracy: 78.12%, F1 Score: 0.63
# Training Size: 34%, Multi-label Validation Accuracy: 79.69%, F1 Score: 0.68
# Training Size: 35%, Multi-label Validation Accuracy: 83.59%, F1 Score: 0.80
# Training Size: 36%, Multi-label Validation Accuracy: 83.20%, F1 Score: 0.78
# Training Size: 37%, Multi-label Validation Accuracy: 85.94%, F1 Score: 0.83
# Training Size: 38%, Multi-label Validation Accuracy: 78.91%, F1 Score: 0.66
# Training Size: 39%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.81
# Training Size: 40%, Multi-label Validation Accuracy: 83.20%, F1 Score: 0.78
# Training Size: 41%, Multi-label Validation Accuracy: 83.59%, F1 Score: 0.80
# Training Size: 42%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.84
# Training Size: 43%, Multi-label Validation Accuracy: 79.30%, F1 Score: 0.65
# Training Size: 43%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.80
# Training Size: 44%, Multi-label Validation Accuracy: 82.03%, F1 Score: 0.73
# Training Size: 46%, Multi-label Validation Accuracy: 83.20%, F1 Score: 0.74
# Training Size: 47%, Multi-label Validation Accuracy: 83.59%, F1 Score: 0.74
# Training Size: 48%, Multi-label Validation Accuracy: 83.20%, F1 Score: 0.76
# Training Size: 49%, Multi-label Validation Accuracy: 85.55%, F1 Score: 0.84
# Training Size: 50%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.80
# Training Size: 51%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.77
# Training Size: 52%, Multi-label Validation Accuracy: 84.77%, F1 Score: 0.78
# Training Size: 53%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.84
# Training Size: 54%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.79
# Training Size: 55%, Multi-label Validation Accuracy: 85.94%, F1 Score: 0.80
# Training Size: 56%, Multi-label Validation Accuracy: 88.28%, F1 Score: 0.86
# Training Size: 57%, Multi-label Validation Accuracy: 85.55%, F1 Score: 0.84
# Training Size: 58%, Multi-label Validation Accuracy: 85.16%, F1 Score: 0.83
# Training Size: 59%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.84
# Training Size: 60%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.82
# Training Size: 61%, Multi-label Validation Accuracy: 84.38%, F1 Score: 0.80
# Training Size: 62%, Multi-label Validation Accuracy: 83.98%, F1 Score: 0.78
# Training Size: 63%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.79
# Training Size: 64%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.85
# Training Size: 65%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.81
# Training Size: 65%, Multi-label Validation Accuracy: 85.94%, F1 Score: 0.78
# Training Size: 67%, Multi-label Validation Accuracy: 85.55%, F1 Score: 0.81
# Training Size: 68%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.85
# Training Size: 69%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.82
# Training Size: 70%, Multi-label Validation Accuracy: 87.89%, F1 Score: 0.83
# Training Size: 71%, Multi-label Validation Accuracy: 85.55%, F1 Score: 0.81
# Training Size: 72%, Multi-label Validation Accuracy: 87.89%, F1 Score: 0.83
# Training Size: 73%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.84
# Training Size: 74%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.82
# Training Size: 75%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.85
# Training Size: 76%, Multi-label Validation Accuracy: 88.28%, F1 Score: 0.86
# Training Size: 77%, Multi-label Validation Accuracy: 87.50%, F1 Score: 0.85
# Training Size: 78%, Multi-label Validation Accuracy: 88.28%, F1 Score: 0.86
# Training Size: 79%, Multi-label Validation Accuracy: 87.50%, F1 Score: 0.85
# Training Size: 80%, Multi-label Validation Accuracy: 85.94%, F1 Score: 0.81
# Training Size: 81%, Multi-label Validation Accuracy: 88.28%, F1 Score: 0.85
# Training Size: 82%, Multi-label Validation Accuracy: 88.67%, F1 Score: 0.86
# Training Size: 83%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.84
# Training Size: 84%, Multi-label Validation Accuracy: 86.72%, F1 Score: 0.84
# Training Size: 85%, Multi-label Validation Accuracy: 86.33%, F1 Score: 0.83
# Training Size: 86%, Multi-label Validation Accuracy: 87.89%, F1 Score: 0.85
# Training Size: 87%, Multi-label Validation Accuracy: 88.67%, F1 Score: 0.83
# Training Size: 88%, Multi-label Validation Accuracy: 87.50%, F1 Score: 0.85
# Training Size: 89%, Multi-label Validation Accuracy: 89.45%, F1 Score: 0.89
# Training Size: 90%, Multi-label Validation Accuracy: 87.11%, F1 Score: 0.83
# Training Size: 91%, Multi-label Validation Accuracy: 88.67%, F1 Score: 0.86
# Training Size: 92%, Multi-label Validation Accuracy: 88.67%, F1 Score: 0.83
# Training Size: 93%, Multi-label Validation Accuracy: 87.89%, F1 Score: 0.84
# Training Size: 94%, Multi-label Validation Accuracy: 88.67%, F1 Score: 0.85
# Training Size: 95%, Multi-label Validation Accuracy: 90.23%, F1 Score: 0.88

# %%
# Extract data for plotting
training_sizes = [result['Training Size'] for result in results]
accuracies = [result['Multi-label Validation Accuracy'] * 100 for result in results]
f1_scores = [result['F1 Score'] *100 for result in results]

# Create a plot
plt.figure(figsize=(10, 6))
plt.plot(training_sizes, accuracies, label='Accuracy', marker='o', linestyle='-', color='b')
plt.plot(training_sizes, f1_scores, label='F1 Score', marker='o', linestyle='-', color='r')

# Set axis labels and legend
plt.xlabel('Training Size (%)')
plt.ylabel('Metrics (%)')
plt.title('Accuracy and F1 Score vs. Training Size')
plt.legend()

# Show the plot
plt.grid()
plt.show()

# %% [markdown]
# # Thank You
